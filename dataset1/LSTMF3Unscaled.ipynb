#
#                     2018-12-17  2018-12-29  2019-01-10  2019-01-22
# Longitude Latitude
# -119.5609 36.1672     -51.0260    -51.1030    -53.1130    -53.6540
# -119.5489 36.0072     -80.9560    -82.2640    -83.5630    -83.4070
# -119.5369 36.0472     -83.1980    -83.6720    -84.9170    -84.5300
# -119.5329 36.0152     -93.6450    -94.7880    -96.0660    -96.0170
# -119.5289 35.9512     -31.5850    -32.0960    -33.1620    -32.8450
# ...                        ...         ...         ...         ...
# -118.9351 35.9912       5.1692      5.8056      3.2722      3.7133
# -118.9331 35.8431       7.0684      8.0765      5.0210      5.4701
# -118.9311 35.6111       6.4902      7.5899      4.7841      5.1107
#           36.0432       4.2067      4.5700      2.6953      2.8795
# -118.9271 35.7791       8.5980      9.5428      6.8206      7.1979
#
# [410 rows x 110 columns]

# %%
dfgw=pd.read_csv('groundwater.csv')
dfgw=dfgw.set_index([dfgw.columns[0],dfgw.columns[1]])
dfgw.columns=pd.to_datetime(dfgw.columns, format='%Y-%m-%d')
dfgw=dfgw.dropna(axis=0, how='all')#drop full nan rows
for y in range(df.columns.size):# includes all dates and adds nans
    if df.columns[y] != dfgw.columns[y]: #if column is misssing insert it
        dfgw.insert(loc=y,column=df.columns[y],value=np.nan*237,allow_duplicates=False)

# %%
for x in range(len(dfgw.index)):
    dfgw.iloc[x]=dfgw.iloc[x].fillna(method='ffill')
    dfgw.iloc[x]=dfgw.iloc[x].fillna(method='bfill')
    
dfgw
# Out:
#                     2014-11-08  2014-12-02  2014-12-26  2015-02-12  \
# Longitude Latitude
# -120.9486 37.6316    81.000000   81.000000   81.000000   81.000000
# -120.8926 36.7114    72.248964   72.248964   72.248964   72.248964
# -120.8846 36.6994    72.248964   72.248964   72.248964   72.248964
# -120.8746 36.6874    72.248964   72.248964   72.248964   72.248964
# -120.1368 35.6991   141.123387  141.123387  141.123387  141.123387
# ...                        ...         ...         ...         ...
# -119.0351 36.3933    17.409091   17.409091   17.409091   17.409091
# -119.0271 36.3793    17.409091   17.409091   17.409091   17.409091
# -119.0571 36.4493    17.409091   17.409091   17.409091   17.409091
# -119.0211 36.3993    17.409091   17.409091   17.409091   17.409091
# -119.0111 36.3873    17.409091   17.409091   17.409091   17.409091
#
#                     2015-03-08  2015-04-01  2015-04-25  2015-05-19  \
# Longitude Latitude
# -120.9486 37.6316    81.000000   81.000000   81.000000   81.000000
# -120.8926 36.7114    72.248964   72.248964   72.248964   72.248964
# -120.8846 36.6994    72.248964   72.248964   72.248964   72.248964
# -120.8746 36.6874    72.248964   72.248964   72.248964   72.248964
# -120.1368 35.6991   141.123387  141.123387  141.123387  141.123387
# ...                        ...         ...         ...         ...
# -119.0351 36.3933    17.409091   17.409091   17.409091   17.409091
# -119.0271 36.3793    17.409091   17.409091   17.409091   17.409091
# -119.0571 36.4493    17.409091   17.409091   17.409091   17.409091
# -119.0211 36.3993    17.409091   17.409091   17.409091   17.409091
# -119.0111 36.3873    17.409091   17.409091   17.409091   17.409091
#
#                     2015-06-12  2015-07-06  ...  2018-10-18  2018-10-30  \
# Longitude Latitude                          ...
# -120.9486 37.6316    81.000000   81.000000  ...   75.653992   75.813688
# -120.8926 36.7114    72.248964   72.248964  ...   75.200000   75.200000
# -120.8846 36.6994    72.248964   72.248964  ...   75.200000   75.200000
# -120.8746 36.6874    72.248964   72.248964  ...   75.200000   75.200000
# -120.1368 35.6991   141.123387  141.123387  ...  150.898190  151.000000
# ...                        ...         ...  ...         ...         ...
# -119.0351 36.3933    17.409091   17.409091  ...   16.978182   17.000000
# -119.0271 36.3793    17.409091   17.409091  ...   16.978182   17.000000
# -119.0571 36.4493    17.409091   17.409091  ...   16.978182   17.000000
# -119.0211 36.3993    17.409091   17.409091  ...   16.978182   17.000000
# -119.0111 36.3873    17.409091   17.409091  ...   16.978182   17.000000
#
#                     2018-11-11  2018-11-17  2018-11-23  2018-12-05  \
# Longitude Latitude
# -120.9486 37.6316    75.973384        76.0        76.0        76.0
# -120.8926 36.7114    75.200000        75.2        75.2        75.2
# -120.8846 36.6994    75.200000        75.2        75.2        75.2
# -120.8746 36.6874    75.200000        75.2        75.2        75.2
# -120.1368 35.6991   151.000000       151.0       151.0       151.0
# ...                        ...         ...         ...         ...
# -119.0351 36.3933    17.000000        17.0        17.0        17.0
# -119.0271 36.3793    17.000000        17.0        17.0        17.0
# -119.0571 36.4493    17.000000        17.0        17.0        17.0
# -119.0211 36.3993    17.000000        17.0        17.0        17.0
# -119.0111 36.3873    17.000000        17.0        17.0        17.0
#
#                     2018-12-17  2018-12-29  2019-01-10  2019-01-22
# Longitude Latitude
# -120.9486 37.6316         76.0        76.0        76.0        76.0
# -120.8926 36.7114         75.2        75.2        75.2        75.2
# -120.8846 36.6994         75.2        75.2        75.2        75.2
# -120.8746 36.6874         75.2        75.2        75.2        75.2
# -120.1368 35.6991        151.0       151.0       151.0       151.0
# ...                        ...         ...         ...         ...
# -119.0351 36.3933         17.0        17.0        17.0        17.0
# -119.0271 36.3793         17.0        17.0        17.0        17.0
# -119.0571 36.4493         17.0        17.0        17.0        17.0
# -119.0211 36.3993         17.0        17.0        17.0        17.0
# -119.0111 36.3873         17.0        17.0        17.0        17.0
#
# [11286 rows x 110 columns]

# %%
drain=pd.read_csv('rainfall.csv')
drain=drain.set_index([drain.columns[0],drain.columns[1]])
drain.columns=pd.to_datetime(drain.columns, format='%Y-%m-%d')
for y in range(df.columns.size):# includes all dates and adds nans
    if df.columns[y] != drain.columns[y]: #if column is misssing insert it
        drain.insert(loc=y,column=df.columns[y],value=np.nan*237,allow_duplicates=False)
drain
# Out:
# C:\Users\jupad\AppData\Local\Temp\ipykernel_13080\1991105724.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   drain.insert(loc=y,column=df.columns[y],value=np.nan*237,allow_duplicates=False)
#                     2014-11-08  2014-12-02  2014-12-26  2015-02-12  \
# Longitude Latitude
# -120.9486 37.6316          NaN         NaN         NaN         NaN
# -120.8926 36.7114          NaN         NaN         NaN         NaN
# -120.8846 36.6994          NaN         NaN         NaN         NaN
# -120.8746 36.6874          NaN         NaN         NaN         NaN
# -120.1368 35.6991          NaN         NaN         NaN         NaN
# ...                        ...         ...         ...         ...
# -119.0351 36.3933          NaN         NaN         NaN         NaN
# -119.0271 36.3793          NaN         NaN         NaN         NaN
# -119.0571 36.4493          NaN         NaN         NaN         NaN
# -119.0211 36.3993          NaN         NaN         NaN         NaN
# -119.0111 36.3873          NaN         NaN         NaN         NaN
#
#                     2015-03-08  2015-04-01  2015-04-25  2015-05-19  \
# Longitude Latitude
# -120.9486 37.6316          NaN         NaN         NaN         NaN
# -120.8926 36.7114          NaN         NaN         NaN         NaN
# -120.8846 36.6994          NaN         NaN         NaN         NaN
# -120.8746 36.6874          NaN         NaN         NaN         NaN
# -120.1368 35.6991          NaN         NaN         NaN         NaN
# ...                        ...         ...         ...         ...
# -119.0351 36.3933          NaN         NaN         NaN         NaN
# -119.0271 36.3793          NaN         NaN         NaN         NaN
# -119.0571 36.4493          NaN         NaN         NaN         NaN
# -119.0211 36.3993          NaN         NaN         NaN         NaN
# -119.0111 36.3873          NaN         NaN         NaN         NaN
#
#                     2015-06-12  2015-07-06  ...    2018-10-18    2018-10-30  \
# Longitude Latitude                          ...
# -120.9486 37.6316          NaN         NaN  ...  1.002529e-08  5.244156e-15
# -120.8926 36.7114          NaN         NaN  ...  0.000000e+00  0.000000e+00
# -120.8846 36.6994          NaN         NaN  ...  0.000000e+00  0.000000e+00
# -120.8746 36.6874          NaN         NaN  ...  0.000000e+00  0.000000e+00
# -120
loc[datain.index[row]].to_numpy().flatten().reshape(-1,datain2.loc[datain.index[row]].shape[-1])).reshape(datain2.loc[datain.index[row]].shape)
        #arr2=scaler.fit_transform(datain3.loc[datain.index[row]].to_numpy().flatten().reshape(-1,datain3.loc[datain.index[row]].shape[-1])).reshape(datain3.loc[datain.index[row]].shape)
        
        arr1=datain2.loc[datain.index[row]].to_numpy().flatten()
        arr2=datain3.loc[datain.index[row]].to_numpy().flatten()
        arr=datain.iloc[row].interpolate().to_numpy().flatten()
        #arr=scaler.fit_transform(arr.reshape(-1,arr.shape[-1])).reshape(arr.shape)

        # arr1=datain3.loc[datain.index[row]].to_numpy().flatten()
        # # print("found", row)
        # arr2=datain2.loc[datain.index[row]].to_numpy().flatten() # rainfall
         
        
        #arr2=np.where(np.isnan(arr2), ma.array(arr2, mask=np.isnan(arr2)).mean(), arr2) 
        arr3=np.concatenate((arr,arr2,arr1)).reshape(features,110)
        
        
        for mth in range(0, len(datain2.columns)-(2*timestep)+1): # Define range lenght of the dates - 2* amount of timesep?? +1
            cnt=cnt+1 # Gives us the number of samples. Later used to reshape the data
            X_start=mth # Start month for inputs of each sample
            X_end=mth+timestep # End month for inputs of each sample
            Y_start=mth+timestep # Start month for targets of each sample. Note, start is inclusive and end is exclusive, that's why X_end and Y_start is the same number
            Y_end=mth+2*timestep # End month for targets of each sample.  
            
            # Assemble input and target arrays containing all samples
            if cnt==1:
                X_comb=arr3[:,X_start:X_end]
                #arr3=scaler.inverse_transform(arr3.reshape(-1,arr3.shape[-1])).reshape(arr3.shape)
                Y_comb=arr3[0][Y_start:Y_end]
            else: 
                X_comb=np.append(X_comb, arr3[:,X_start:X_end])
                #arr3=scaler.inverse_transform(arr3.reshape(-1,arr3.shape[-1])).reshape(arr3.shape)
                Y_comb=np.append(Y_comb, arr3[:1,Y_start:Y_end])
    
    # Reshape input and target arrays
    X_out=np.reshape(X_comb, (cnt, timestep, features))
    Y_out=np.reshape(Y_comb, (cnt, timestep, 1))
    return X_out, Y_out

# %% [markdown]
# ##### Step 2 - Split and Shape data

# %%
#Divides data into 80% training 20% testing
#train, test = train_test_split(df, test_size=0.2)
# creates sequences to train
# X , Y = shaping(datain=df, timestep= timestep )
# X_train, X_test, Y_train, Y_test = train_test_split(X,Y , test_size=0.2, random_state=28)
# nsamples, nx, ny = X_train.shape
# X_train = X_train.reshape((nsamples,nx*ny))
# nsamples, nx, ny = Y_train.shape
# Y_train = Y_train.reshape((nsamples,nx*ny))
# nsamples, nx, ny = X_test.shape
# X_test = X_test.reshape((nsamples,nx*ny))
# nsamples, nx, ny = Y_test.shape
# Y_test = Y_test.reshape((nsamples,nx*ny))
#Divides data into 80% training 20% testing
features=3


# creates sequences to train
shuffled = df.sample(frac=1)
# shuffled=scaler.fit_transform(shuffled)
# scaler.transform(drain)
# scaler.transform(dfgw)

X_train, Y_train = shaping3(datain=shuffled,datain2=drain,datain3=dfgw, timestep= timestep,features=features )
test=pd.read_csv('dataset1/testset170.csv')
test=test.set_index([test.columns[0],test.columns[1]])
test.columns=pd.to_datetime(test.columns, format='%Y-%m-%d')
test=test.dropna(axis=0, how='all')#drop full nan rows

X_test, Y_test = shaping3(datain=test,datain2=drain,datain3=dfgw, timestep= timestep,features=features )



# Y_train=scaler2.fit_transform(Y_train.reshape(-1,Y_train.shape[-1])).reshape(Y_train.shape)
# Y_test=scaler2.transform(Y_test.reshape(-1,Y_test.shape[-1])).reshape(Y_test.shape)

# %%
# scaler = MinMaxScaler()
# scaler2 = MinMaxScaler()
# X_train = scaler.fit_transform(X_train.reshape(-1, X_train.shape[-1])).reshape(X_train.shape)
# X_test = scaler.transform(X_test.reshape(-1, X_test.shape[-1])).reshape(X_test.shape)
# Y_train = scaler2.fit_transform(Y_train.reshape(-1, Y_train.shape[-1])).reshape(Y_train.shape)
# Y_test = scaler2.transform(Y_test.reshape(-1, Y_test.shape[-1])).reshape(Y_test.shape)

# %% [markdown]
# ##### Step 3 - Specify the structure of a Neural Network, first model

# %%
callback = callbacks.EarlyStopping(monitor='loss', patience=3)
model2 = Sequential(name="biLSTM-Model") # Model
#model2.add(Masking(mask_value=-1000, input_shape=(timestep, 1)))

model2.add(Input(shape=(X_train.shape[1],X_train.shape[2]), name='Input-Layer')) # Input Layer - need to speicfy the shape of inputs
model2.add(LSTM(units=64, activation='relu', recurrent_activation='sigmoid', stateful=False, return_sequences=True)) 
model2.add(TimeDistributed(Dense(units=1, activation='linear'), name='Output-Layer')) # Output Layer, Linear(x) = x
#optimizer=Adam(.005)
model2.compile(optimizer='adam', # default='rmsprop', an algorithm to be used in backpropagation
              loss='mean_squared_error', # Loss function to be optimized. A string (name of loss function), or a tf.keras.losses.Loss instance.
                metrics=['MeanSquaredError', 'mean_absolute_error'], # List of metrics to be evaluated by the model during training and testing. Each of this can be a string (name of a built-in function), function or a tf.keras.metrics.Metric instance. 
              loss_weights=None, # default=None, Optional list or dictionary specifying scalar coefficients (Python floats) to weight the loss contributions of different model outputs.
              weighted_metrics=None, # default=None, List of metrics to be evaluated and weighted by sample_weight or class_weight during training and testing.
              run_eagerly=None, # Defaults to False. If True, this Model's logic will not be wrapped in a tf.function. Recommended to leave this as None unless your Model cannot be run inside a tf.function.
              steps_per_execution=None, # Defaults to 1. The number of batches to run during each tf.function call. Running multiple batches inside a single tf.function call can greatly improve performance on TPUs or small models with a large Python overhead.
                   
             )

# %%
##### Train model

# %%
history = model2.fit(X_train, # input data
                    Y_train, # target data
                    batch_size=32, # Number of samples per gradient update. If unspecified, batch_size will default to 32.
                    epochs=100, # default=1, Number of epochs to train the model. An epoch is an iteration over the entire x and y data provided
                    verbose=2, # default='auto', ('auto', 0, 1, or 2). Verbosity mode. 0 = silent, 1 = progress bar, 2 = one line per epoch. 'auto' defaults to 1 for most cases, but 2 when used with ParameterServerStrategy.
                    callbacks=None, # default=None, list of callbacks to apply during training. See tf.keras.callbacks
                    validation_split=0.142, # default=0.0, Fraction of the training data to be used as validation data. The model will set apart this fraction of the training data, will not train on it, and will evaluate the loss and any model metrics on this data at the end of each epoch. 
                    #validation_data=(X_test, y_test), # default=None, Data on which to evaluate the loss and any model metrics at the end of each epoch. 
                    shuffle=True, # default=True, Boolean (whether to shuffle the training data before each epoch) or str (for 'batch').
                    class_weight=None, # default=None, Optional dictionary mapping class indices (integers) to a weight (float) value, used for weighting the loss function (during training only). This can be useful to tell the model to "pay more attention" to samples from an under-represented class.
                    sample_weight=None, # default=None, Optional Numpy array of weights for the training samples, used for weighting the loss function (during training only).
                    initial_epoch=0, # Integer, default=0, Epoch at which to start training (useful for resuming a previous training run).
                    steps_per_epoch=None, # Integer or None, default=None, Total number of steps (batches of samples) before declaring one epoch finished and starting the next epoch. When training with input tensors such as TensorFlow data tensors, the default None is equal to the number of samples in your dataset divided by the batch size, or 1 if that cannot be determined. 
                    validation_steps=None, # Only relevant if validation_data is provided and is a tf.data dataset. Total number of steps (batches of samples) to draw before stopping when performing validation at the end of every epoch.
                    validation_batch_size=None, # Integer or None, default=None, Number of samples per validation batch. If unspecified, will default to batch_size.
                    validation_freq=1, # default=1, Only relevant if validation data is provided. If an integer, specifies how many training epochs to run before a new validation run is performed, e.g. validation_freq=2 runs validation every 2 epochs.
                    max_queue_size=10, # default=10, Used for generator or keras.utils.Sequence input only. Maximum size for the generator queue. If unspecified, max_queue_size will default to 10.
                    workers=1, # default=1, Used for generator or keras.utils.Sequence input only. Maximum number of processes to spin up when using process-based threading. If unspecified, workers will default to 1.
                    use_multiprocessing=True, # default=False, Used for generator or keras.utils.Sequence input only. If True, use process-based threading. If unspecified, use_multiprocessing will default to False. 
                
                   )
# Out:
# Epoch 1/100
# 1001/1001 - 42s - loss: 40.2671 - mean_squared_error: 40.2671 - mean_absolute_error: 3.7362 - val_loss: 11.6856 - val_mean_squared_error: 11.6856 - val_mean_absolute_error: 2.4012 - 42s/epoch - 42ms/step
# Epoch 2/100
# 1001/1001 - 13s - loss: 11.6328 - mean_squared_error: 11.6328 - mean_absolute_error: 2.4788 - val_loss: 10.2535 - val_mean_squared_error: 10.2535 - val_mean_absolute_error: 2.3239 - 13s/epoch - 13ms/step
# Epoch 3/100
# 1001/1001 - 13s - loss: 10.2287 - mean_squared_error: 10.2287 - mean_absolute_error: 2.3365 - val_loss: 10.5990 - val_mean_squared_error: 10.5990 - val_mean_absolute_error: 2.4836 - 13s/epoch - 13ms/step
# Epoch 4/100
# 1001/1001 - 13s - loss: 9.9777 - mean_squared_error: 9.9777 - mean_absolute_error: 2.3035 - val_loss: 9.5363 - val_mean_squared_error: 9.5363 - val_mean_absolute_error: 2.2600 - 13s/epoch - 13ms/step
# Epoch 5/100
# 1001/1001 - 13s - loss: 9.0701 - mean_squared_error: 9.0701 - mean_absolute_error: 2.2152 - val_loss: 8.4114 - val_mean_squared_error: 8.4114 - val_mean_absolute_error: 2.1167 - 13s/epoch - 13ms/step
# Epoch 6/100
# 1001/1001 - 14s - loss: 8.5274 - mean_squared_error: 8.5274 - mean_absolute_error: 2.1423 - val_loss: 8.1686 - val_mean_squared_error: 8.1686 - val_mean_absolute_error: 2.1254 - 14s/epoch - 14ms/step
# Epoch 7/100
# 1001/1001 - 13s - loss: 8.2597 - mean_squared_error: 8.2597 - mean_absolute_error: 2.1069 - val_loss: 7.8701 - val_mean_squared_error: 7.8701 - val_mean_absolute_error: 1.9791 - 13s/epoch - 13ms/step
# Epoch 8/100
# 1001/1001 - 13s - loss: 7.8784 - mean_squared_error: 7.8784 - mean_absolute_error: 2.0518 - val_loss: 7.8352 - val_mean_squared_error: 7.8352 - val_mean_absolute_error: 2.0599 - 13s/epoch - 13ms/step
# Epoch 9/100
# 1001/1001 - 13s - loss: 7.7425 - mean_squared_error: 7.7425 - mean_absolute_error: 2.0323 - val_loss: 7.0317 - val_mean_squared_error: 7.0317 - val_mean_absolute_error: 1.9157 - 13s/epoch - 13ms/step
# Epoch 10/100
# 1001/1001 - 12s - loss: 7.4397 - mean_squared_error: 7.4397 - mean_absolute_error: 1.9828 - val_loss: 6.7942 - val_mean_squared_error: 6.7942 - val_mean_absolute_error: 1.8626 - 12s/epoch - 12ms/step
# Epoch 11/100
# 1001/1001 - 13s - loss: 7.6145 - mean_squared_error: 7.6145 - mean_absolute_error: 2.0120 - val_loss: 6.9976 - val_mean_squared_error: 6.9976 - val_mean_absolute_error: 1.8787 - 13s/epoch - 13ms/step
# Epoch 12/100
# 1001/1001 - 13s - loss: 7.1102 - mean_squared_error: 7.1102 - mean_absolute_error: 1.9303 - val_loss: 7.1810 - val_mean_squared_error: 7.1810 - val_mean_absolute_error: 1.9376 - 13s/epoch - 13ms/step
# Epoch 13/100
# 1001/1001 - 13s - loss: 6.9805 - mean_squared_error: 6.9805 - mean_absolute_error: 1.9085 - val_loss: 6.3699 - val_mean_squared_error: 6.3699 - val_mean_absolute_error: 1.8026 - 13s/epoch - 13ms/step
# Epoch 14/100
# 1001/1001 - 12s - loss: 6.7814 - mean_squared_error: 6.7814 - mean_absolute_error: 1.8736 - val_loss: 6.7454 - val_mean_squared_error: 6.7454 - val_mean_absolute_error: 1.8686 - 12s/epoch - 12ms/step
# Epoch 15/100
# 1001/1001 - 13s - loss: 6.7122 - mean_squared_error: 6.7122 - mean_absolute_error: 1.8631 - val_loss: 6.7303 - val_mean_squared_error: 6.7303 - val_mean_absolute_error: 1.8848 - 13s/epoch - 13ms/step
# Epoch 16/100
# 1001/1001 - 12s - loss: 6.6391 - mean_squared_error: 6.6391 - mean_absolute_error: 1.8522 - val_loss: 6.2877 - val_mean_squared_error: 6.2877 - val_mean_absolute_error: 1.7625 - 12s/epoch - 12ms/step
# Epoch 17/100
# 1001/1001 - 13s - loss: 6.4967 - mean_squared_error: 6.4967 - mean_absolute_error: 1.8248 - val_loss: 6.6089 - val_mean_squared_error: 6.6089 - val_mean_absolute_error: 1.8133 - 13s/epoch - 13ms/step
# Epoch 18/100
# 1001/1001 - 10s - loss: 6.3979 - mean_squared_error: 6.3979 - mean_absolute_error: 1.8069 - val_loss: 6.0315 - val_mean_squared_error: 6.0315 - val_mean_absolute_error: 1.7321 - 10s/epoch - 10ms/step
# Epoch 19/100
# 1001/1001 - 9s - loss: 6.3359 - mean_squared_error: 6.3359 - mean_absolute_error: 1.7943 - val_loss: 6.2290 - val_mean_squared_error: 6.2290 - val_mean_absolute_error: 1.7918 - 9s/epoch - 9ms/step
# Epoch 20/100
# 1001/1001 - 8s - loss: 6.2171 - mean_squared_error: 6.2171 - mean_absolute_error: 1.7756 - val_loss: 5.9154 - val_mean_squared_error: 5.9154 - val_mean_absolute_error: 1.7195 - 8s/epoch - 8ms/step
# Epoch 21/100
# 1001/1001 - 8s - loss: 6.2301 - mean_squared_error: 6.2301 - mean_absolute_error: 1.7783 - val_loss: 5.9026 - val_mean_squared_error: 5.9026 - val_mean_absolute_error: 1.7063 - 8s/epoch - 8ms/step
# Epoch 22/100
# 1001/1001 - 9s - loss: 6.1527 - mean_squared_error: 6.1527 - mean_absolute_error: 1.7647 - val_loss: 5.8845 - val_mean_squared_error: 5.8845 - val_mean_absolute_error: 1.6977 - 9s/epoch - 9ms/step
# Epoch 23/100
# 1001/1001 - 9s - loss: 5.9756 - mean_squared_error: 5.9756 - mean_absolute_error: 1.7319 - val_loss: 5.5980 - val_mean_squared_error: 5.5980 - val_mean_absolute_error: 1.6544 - 9s/epoch - 9ms/step
# Epoch 24/100
# 1001/1001 - 8s - loss: 5.9578 - mean_squared_error: 5.9578 - mean_absolute_error: 1.7282 - val_loss: 6.1869 - val_mean_squared_error: 6.1869 - val_mean_absolute_error: 1.7659 - 8s/epoch - 8ms/step
# Epoch 25/100
# 1001/1001 - 8s - loss: 5.8890 - mean_squared_error: 5.8890 - mean_absolute_error: 1.7161 - val_loss: 5.6255 - val_mean_squared_error: 5.6255 - val_mean_absolute_error: 1.6638 - 8s/epoch - 8ms/step
# Epoch 26/100
# 1001/1001 - 8s - loss: 5.8509 - mean_squared_error: 5.8509 - mean_absolute_error: 1.7107 - val_loss: 5.6090 - val_mean_squared_error: 5.6090 - val_mean_absolute_error: 1.6709 - 8s/epoch - 8ms/step
# Epoch 27/100
# 1001/1001 - 8s - loss: 5.7688 - mean_squared_error: 5.7688 - mean_absolute_error: 1.6951 - val_loss: 5.8659 - val_mean_squared_error: 5.8659 - val_mean_absolute_error: 1.7278 - 8s/epoch - 8ms/step
# Epoch 28/100
# 1001/1001 - 8s - loss: 5.6743 - mean_squared_error: 5.6743 - mean_absolute_error: 1.6784 - val_loss: 5.3209 - val_mean_squared_error: 5.3209 - val_mean_absolute_error: 1.6202 - 8s/epoch - 8ms/step
# Epoch 29/100
# 1001/1001 - 8s - loss: 5.6354 - mean_squared_error: 5.6354 - mean_absolute_error: 1.6684 - val_loss: 5.6155 - val_mean_squared_error: 5.6155 - val_mean_absolute_error: 1.6348 - 8s/epoch - 8ms/step
# Epoch 30/100
# 1001/1001 - 8s - loss: 5.6215 - mean_squared_error: 5.6215 - mean_absolute_error: 1.6688 - val_loss: 5.4046 - val_mean_squared_error: 5.4046 - val_mean_absolute_error: 1.6324 - 8s/epoch - 8ms/step
# Epoch 31/100
# 1001/1001 - 8s - loss: 5.5765 - mean_squared_error: 5.5765 - mean_absolute_error: 1.6591 - val_loss: 5.2603 - val_mean_squared_error: 5.2603 - val_mean_absolute_error: 1.6093 - 8s/epoch - 8ms/step
# Epoch 32/100
# 1001/1001 - 8s - loss: 5.5361 - mean_squared_error: 5.5361 - mean_absolute_error: 1.6536 - val_loss: 5.5113 - val_mean_squared_error: 5.5113 - val_mean_absolute_error: 1.6413 - 8s/epoch - 8ms/step
# Epoch 33/100
# 1001/1001 - 8s - loss: 5.4722 - mean_squared_error: 5.4722 - mean_absolute_error: 1.6402 - val_loss: 5.3721 - val_mean_squared_error: 5.3721 - val_mean_absolute_error: 1.6118 - 8s/epoch - 8ms/step
# Epoch 34/100
# 1001/1001 - 8s - loss: 5.4410 - mean_squared_error: 5.4410 - mean_absolute_error: 1.6350 - val_loss: 5.4001 - val_mean_squared_error: 5.4001 - val_mean_absolute_error: 1.6061 - 8s/epoch - 8ms/step
# Epoch 35/100
# 1001/1001 - 8s - loss: 5.4053 - mean_squared_error: 5.4053 - mean_absolute_error: 1.6296 - val_loss: 5.3737 - val_mean_squared_error: 5.3737 - val_mean_absolute_error: 1.6101 - 8s/epoch - 8ms/step
# Epoch 36/100
# 1001/1001 - 8s - loss: 5.3550 - mean_squared_error: 5.3550 - mean_absolute_error: 1.6185 - val_loss: 5.3628 - val_mean_squared_error: 5.3628 - val_mean_absolute_error: 1.6018 - 8s/epoch - 8ms/step
# Epoch 37/100
# 1001/1001 - 8s - loss: 5.3678 - mean_squared_error: 5.3678 - mean_absolute_error: 1.6204 - val_loss: 5.9890 - val_mean_squared_error: 5.9890 - val_mean_absolute_error: 1.7211 - 8s/epoch - 8ms/step
# Epoch 38/100
# 1001/1001 - 8s - loss: 5.2867 - mean_squared_error: 5.2867 - mean_absolute_error: 1.6061 - val_loss: 5.1087 - val_mean_squared_error: 5.1087 - val_mean_absolute_error: 1.5465 - 8s/epoch - 8ms/step
# Epoch 39/100
# 1001/1001 - 7s - loss: 5.2433 - mean_squared_error: 5.2433 - mean_absolute_error: 1.5961 - val_loss: 5.1768 - val_mean_squared_error: 5.1768 - val_mean_absolute_error: 1.5999 - 7s/epoch - 7ms/step
# Epoch 40/100
# 1001/1001 - 6s - loss: 5.2334 - mean_squared_error: 5.2334 - mean_absolute_error: 1.5967 - val_loss: 5.3272 - val_mean_squared_error: 5.3272 - val_mean_absolute_error: 1.6351 - 6s/epoch - 6ms/step
# Epoch 41/100
# 1001/1001 - 5s - loss: 5.2114 - mean_squared_error: 5.2114 - mean_absolute_error: 1.5916 - val_loss: 5.1251 - val_mean_squared_error: 5.1251 - val_mean_absolute_error: 1.5725 - 5s/epoch - 5ms/step
# Epoch 42/100
# 1001/1001 - 5s - loss: 5.1728 - mean_squared_error: 5.1728 - mean_absolute_error: 1.5844 - val_loss: 5.0472 - val_mean_squared_error: 5.0472 - val_mean_absolute_error: 1.5752 - 5s/epoch - 5ms/step
# Epoch 43/100
# 1001/1001 - 5s - loss: 5.1773 - mean_squared_error: 5.1774 - mean_absolute_error: 1.5857 - val_loss: 5.2145 - val_mean_squared_error: 5.2145 - val_mean_absolute_error: 1.6208 - 5s/epoch - 5ms/step
# Epoch 44/100
# 1001/1001 - 5s - loss: 5.1203 - mean_squared_error: 5.1203 - mean_absolute_error: 1.5773 - val_loss: 5.0301 - val_mean_squared_error: 5.0301 - val_mean_absolute_error: 1.5722 - 5s/epoch - 5ms/step
# Epoch 45/100
# 1001/1001 - 5s - loss: 5.1091 - mean_squared_error: 5.1091 - mean_absolute_error: 1.5752 - val_loss: 4.9371 - val_mean_squared_error: 4.9371 - val_mean_absolute_error: 1.5313 - 5s/epoch - 5ms/step
# Epoch 46/100
# 1001/1001 - 5s - loss: 5.1064 - mean_squared_error: 5.1064 - mean_absolute_error: 1.5732 - val_loss: 4.9915 - val_mean_squared_error: 4.9915 - val_mean_absolute_error: 1.5418 - 5s/epoch - 5ms/step
# Epoch 47/100
# 1001/1001 - 5s - loss: 5.0343 - mean_squared_error: 5.0343 - mean_absolute_error: 1.5579 - val_loss: 4.9407 - val_mean_squared_error: 4.9407 - val_mean_absolute_error: 1.5255 - 5s/epoch - 5ms/step
# Epoch 48/100
# 1001/1001 - 5s - loss: 5.0126 - mean_squared_error: 5.0126 - mean_absolute_error: 1.5548 - val_loss: 4.7781 - val_mean_squared_error: 4.7781 - val_mean_absolute_error: 1.4971 - 5s/epoch - 5ms/step
# Epoch 49/100
# 1001/1001 - 5s - loss: 5.0406 - mean_squared_error: 5.0406 - mean_absolute_error: 1.5614 - val_loss: 4.9002 - val_mean_squared_error: 4.9002 - val_mean_absolute_error: 1.5221 - 5s/epoch - 5ms/step
# Epoch 50/100
# 1001/1001 - 5s - loss: 4.9967 - mean_squared_error: 4.9967 - mean_absolute_error: 1.5525 - val_loss: 4.9935 - val_mean_squared_error: 4.9935 - val_mean_absolute_error: 1.5581 - 5s/epoch - 5ms/step
# Epoch 51/100
# 1001/1001 - 5s - loss: 4.9943 - mean_squared_error: 4.9942 - mean_absolute_error: 1.5515 - val_loss: 4.9247 - val_mean_squared_error: 4.9247 - val_mean_absolute_error: 1.5308 - 5s/epoch - 5ms/step
# Epoch 52/100
# 1001/1001 - 5s - loss: 4.9218 - mean_squared_error: 4.9218 - mean_absolute_error: 1.5349 - val_loss: 4.9806 - val_mean_squared_error: 4.9806 - val_mean_absolute_error: 1.5504 - 5s/epoch - 5ms/step
# Epoch 53/100
# 1001/1001 - 5s - loss: 4.9714 - mean_squared_error: 4.9714 - mean_absolute_error: 1.5466 - val_loss: 4.8915 - val_mean_squared_error: 4.8915 - val_mean_absolute_error: 1.5214 - 5s/epoch - 5ms/step
# Epoch 54/100
# 1001/1001 - 5s - loss: 4.9055 - mean_squared_error: 4.9055 - mean_absolute_error: 1.5342 - val_loss: 4.6744 - val_mean_squared_error: 4.6744 - val_mean_absolute_error: 1.4911 - 5s/epoch - 5ms/step
# Epoch 55/100
# 1001/1001 - 5s - loss: 4.8826 - mean_squared_error: 4.8826 - mean_absolute_error: 1.5300 - val_loss: 4.7367 - val_mean_squared_error: 4.7367 - val_mean_absolute_error: 1.4924 - 5s/epoch - 5ms/step
# Epoch 56/100
# 1001/1001 - 5s - loss: 4.8720 - mean_squared_error: 4.8720 - mean_absolute_error: 1.5300 - val_loss: 4.8998 - val_mean_squared_error: 4.8998 - val_mean_absolute_error: 1.5343 - 5s/epoch - 5ms/step
# Epoch 57/100
# 1001/1001 - 5s - loss: 4.8521 - mean_squared_error: 4.8521 - mean_absolute_error: 1.5256 - val_loss: 4.7069 - val_mean_squared_error: 4.7069 - val_mean_absolute_error: 1.4870 - 5s/epoch - 5ms/step
# Epoch 58/100
# 1001/1001 - 5s - loss: 4.8258 - mean_squared_error: 4.8258 - mean_absolute_error: 1.5177 - val_loss: 4.7474 - val_mean_squared_error: 4.7474 - val_mean_absolute_error: 1.4837 - 5s/epoch - 5ms/step
# Epoch 59/100
# 1001/1001 - 5s - loss: 4.8566 - mean_squared_error: 4.8566 - mean_absolute_error: 1.5235 - val_loss: 4.6396 - val_mean_squared_error: 4.6396 - val_mean_absolute_error: 1.4690 - 5s/epoch - 5ms/step
# Epoch 60/100
# 1001/1001 - 5s - loss: 4.8026 - mean_squared_error: 4.8026 - mean_absolute_error: 1.5129 - val_loss: 4.9290 - val_mean_squared_error: 4.9290 - val_mean_absolute_error: 1.5529 - 5s/epoch - 5ms/step
# Epoch 61/100
# 1001/1001 - 5s - loss: 4.7743 - mean_squared_error: 4.7743 - mean_absolute_error: 1.5087 - val_loss: 4.7983 - val_mean_squared_error: 4.7983 - val_mean_absolute_error: 1.5076 - 5s/epoch - 5ms/step
# Epoch 62/100
# 1001/1001 - 5s - loss: 4.7659 - mean_squared_error: 4.7659 - mean_absolute_error: 1.5052 - val_loss: 4.7999 - val_mean_squared_error: 4.7999 - val_mean_absolute_error: 1.5020 - 5s/epoch - 5ms/step
# Epoch 63/100
# 1001/1001 - 5s - loss: 4.7503 - mean_squared_error: 4.7503 - mean_absolute_error: 1.5035 - val_loss: 4.6379 - val_mean_squared_error: 4.6379 - val_mean_absolute_error: 1.4783 - 5s/epoch - 5ms/step
# Epoch 64/100
# 1001/1001 - 5s - loss: 4.7568 - mean_squared_error: 4.7568 - mean_absolute_error: 1.5045 - val_loss: 5.5740 - val_mean_squared_error: 5.5740 - val_mean_absolute_error: 1.6417 - 5s/epoch - 5ms/step
# Epoch 65/100
# 1001/1001 - 5s - loss: 4.7715 - mean_squared_error: 4.7715 - mean_absolute_error: 1.5125 - val_loss: 4.8153 - val_mean_squared_error: 4.8153 - val_mean_absolute_error: 1.5201 - 5s/epoch - 5ms/step
# Epoch 66/100
# 1001/1001 - 5s - loss: 4.7436 - mean_squared_error: 4.7436 - mean_absolute_error: 1.5032 - val_loss: 4.7423 - val_mean_squared_error: 4.7423 - val_mean_absolute_error: 1.4682 - 5s/epoch - 5ms/step
# Epoch 67/100
# 1001/1001 - 5s - loss: 4.6612 - mean_squared_error: 4.6612 - mean_absolute_error: 1.4848 - val_loss: 4.6938 - val_mean_squared_error: 4.6938 - val_mean_absolute_error: 1.4993 - 5s/epoch - 5ms/step
# Epoch 68/100
# 1001/1001 - 5s - loss: 4.9817 - mean_squared_error: 4.9817 - mean_absolute_error: 1.5532 - val_loss: 4.5702 - val_mean_squared_error: 4.5702 - val_mean_absolute_error: 1.4550 - 5s/epoch - 5ms/step
# Epoch 69/100
# 1001/1001 - 5s - loss: 4.6724 - mean_squared_error: 4.6724 - mean_absolute_error: 1.4887 - val_loss: 4.8661 - val_mean_squared_error: 4.8661 - val_mean_absolute_error: 1.5438 - 5s/epoch - 5ms/step
# Epoch 70/100
# 1001/1001 - 5s - loss: 4.7408 - mean_squared_error: 4.7408 - mean_absolute_error: 1.5047 - val_loss: 4.9092 - val_mean_squared_error: 4.9092 - val_mean_absolute_error: 1.5235 - 5s/epoch - 5ms/step
# Epoch 71/100
# 1001/1001 - 5s - loss: 4.6950 - mean_squared_error: 4.6950 - mean_absolute_error: 1.4917 - val_loss: 4.8447 - val_mean_squared_error: 4.8447 - val_mean_absolute_error: 1.4875 - 5s/epoch - 5ms/step
# Epoch 72/100
# 1001/1001 - 5s - loss: 4.5969 - mean_squared_error: 4.5969 - mean_absolute_error: 1.4696 - val_loss: 4.6942 - val_mean_squared_error: 4.6942 - val_mean_absolute_error: 1.4581 - 5s/epoch - 5ms/step
# Epoch 73/100
# 1001/1001 - 5s - loss: 4.6701 - mean_squared_error: 4.6701 - mean_absolute_error: 1.4884 - val_loss: 4.6071 - val_mean_squared_error: 4.6071 - val_mean_absolute_error: 1.4722 - 5s/epoch - 5ms/step
# Epoch 74/100
# 1001/1001 - 5s - loss: 4.6457 - mean_squared_error: 4.6457 - mean_absolute_error: 1.4816 - val_loss: 4.8514 - val_mean_squared_error: 4.8514 - val_mean_absolute_error: 1.4975 - 5s/epoch - 5ms/step
# Epoch 75/100
# 1001/1001 - 5s - loss: 4.6258 - mean_squared_error: 4.6258 - mean_absolute_error: 1.4777 - val_loss: 4.8215 - val_mean_squared_error: 4.8215 - val_mean_absolute_error: 1.5291 - 5s/epoch - 5ms/step
# Epoch 76/100
# 1001/1001 - 5s - loss: 4.5794 - mean_squared_error: 4.5794 - mean_absolute_error: 1.4688 - val_loss: 4.8059 - val_mean_squared_error: 4.8059 - val_mean_absolute_error: 1.4696 - 5s/epoch - 5ms/step
# Epoch 77/100
# 1001/1001 - 5s - loss: 4.6071 - mean_squared_error: 4.6071 - mean_absolute_error: 1.4743 - val_loss: 4.5340 - val_mean_squared_error: 4.5340 - val_mean_absolute_error: 1.4576 - 5s/epoch - 5ms/step
# Epoch 78/100
# 1001/1001 - 5s - loss: 4.5567 - mean_squared_error: 4.5567 - mean_absolute_error: 1.4614 - val_loss: 5.0721 - val_mean_squared_error: 5.0721 - val_mean_absolute_error: 1.5479 - 5s/epoch - 5ms/step
# Epoch 79/100
# 1001/1001 - 5s - loss: 4.5703 - mean_squared_error: 4.5703 - mean_absolute_error: 1.4674 - val_loss: 4.5429 - val_mean_squared_error: 4.5429 - val_mean_absolute_error: 1.4672 - 5s/epoch - 5ms/step
# Epoch 80/100
# 1001/1001 - 5s - loss: 4.5702 - mean_squared_error: 4.5702 - mean_absolute_error: 1.4665 - val_loss: 5.2474 - val_mean_squared_error: 5.2474 - val_mean_absolute_error: 1.5551 - 5s/epoch - 5ms/step
# Epoch 81/100
# 1001/1001 - 5s - loss: 4.5567 - mean_squared_error: 4.5567 - mean_absolute_error: 1.4630 - val_loss: 4.7738 - val_mean_squared_error: 4.7738 - val_mean_absolute_error: 1.5001 - 5s/epoch - 5ms/step
# Epoch 82/100
# 1001/1001 - 5s - loss: 4.5400 - mean_squared_error: 4.5400 - mean_absolute_error: 1.4602 - val_loss: 4.7749 - val_mean_squared_error: 4.7749 - val_mean_absolute_error: 1.4621 - 5s/epoch - 5ms/step
# Epoch 83/100
# 1001/1001 - 5s - loss: 4.5124 - mean_squared_error: 4.5124 - mean_absolute_error: 1.4531 - val_loss: 4.3672 - val_mean_squared_error: 4.3672 - val_mean_absolute_error: 1.4250 - 5s/epoch - 5ms/step
# Epoch 84/100
# 1001/1001 - 5s - loss: 4.5059 - mean_squared_error: 4.5059 - mean_absolute_error: 1.4520 - val_loss: 4.3555 - val_mean_squared_error: 4.3555 - val_mean_absolute_error: 1.4063 - 5s/epoch - 5ms/step
# Epoch 85/100
# 1001/1001 - 5s - loss: 4.4783 - mean_squared_error: 4.4783 - mean_absolute_error: 1.4450 - val_loss: 4.5976 - val_mean_squared_error: 4.5976 - val_mean_absolute_error: 1.4622 - 5s/epoch - 5ms/step
# Epoch 86/100
# 1001/1001 - 6s - loss: 4.5727 - mean_squared_error: 4.5727 - mean_absolute_error: 1.4665 - val_loss: 5.1881 - val_mean_squared_error: 5.1881 - val_mean_absolute_error: 1.5416 - 6s/epoch - 6ms/step
# Epoch 87/100
# 1001/1001 - 6s - loss: 4.4241 - mean_squared_error: 4.4241 - mean_absolute_error: 1.4333 - val_loss: 4.5999 - val_mean_squared_error: 4.5999 - val_mean_absolute_error: 1.4611 - 6s/epoch - 6ms/step
# Epoch 88/100
# 1001/1001 - 6s - loss: 4.5257 - mean_squared_error: 4.5257 - mean_absolute_error: 1.4565 - val_loss: 4.3850 - val_mean_squared_error: 4.3850 - val_mean_absolute_error: 1.4192 - 6s/epoch - 6ms/step
# Epoch 89/100
# 1001/1001 - 6s - loss: 4.4800 - mean_squared_error: 4.4800 - mean_absolute_error: 1.4452 - val_loss: 4.6031 - val_mean_squared_error: 4.6031 - val_mean_absolute_error: 1.4734 - 6s/epoch - 6ms/step
# Epoch 90/100
# 1001/1001 - 5s - loss: 4.4820 - mean_squared_error: 4.4820 - mean_absolute_error: 1.4473 - val_loss: 4.4397 - val_mean_squared_error: 4.4397 - val_mean_absolute_error: 1.4322 - 5s/epoch - 5ms/step
# Epoch 91/100
# 1001/1001 - 5s - loss: 4.4698 - mean_squared_error: 4.4698 - mean_absolute_error: 1.4440 - val_loss: 4.5407 - val_mean_squared_error: 4.5407 - val_mean_absolute_error: 1.4441 - 5s/epoch - 5ms/step
# Epoch 92/100
# 1001/1001 - 5s - loss: 4.4325 - mean_squared_error: 4.4325 - mean_absolute_error: 1.4366 - val_loss: 4.4891 - val_mean_squared_error: 4.4891 - val_mean_absolute_error: 1.4355 - 5s/epoch - 5ms/step
# Epoch 93/100
# 1001/1001 - 5s - loss: 4.4409 - mean_squared_error: 4.4409 - mean_absolute_error: 1.4389 - val_loss: 4.5364 - val_mean_squared_error: 4.5364 - val_mean_absolute_error: 1.4401 - 5s/epoch - 5ms/step
# Epoch 94/100
# 1001/1001 - 5s - loss: 4.4687 - mean_squared_error: 4.4687 - mean_absolute_error: 1.4458 - val_loss: 4.5382 - val_mean_squared_error: 4.5382 - val_mean_absolute_error: 1.4575 - 5s/epoch - 5ms/step
# Epoch 95/100
# 1001/1001 - 5s - loss: 4.4507 - mean_squared_error: 4.4507 - mean_absolute_error: 1.4397 - val_loss: 4.4078 - val_mean_squared_error: 4.4078 - val_mean_absolute_error: 1.4318 - 5s/epoch - 5ms/step
# Epoch 96/100
# 1001/1001 - 5s - loss: 4.3842 - mean_squared_error: 4.3842 - mean_absolute_error: 1.4254 - val_loss: 4.4172 - val_mean_squared_error: 4.4172 - val_mean_absolute_error: 1.4338 - 5s/epoch - 5ms/step
# Epoch 97/100
# 1001/1001 - 6s - loss: 4.3965 - mean_squared_error: 4.3965 - mean_absolute_error: 1.4289 - val_loss: 4.8858 - val_mean_squared_error: 4.8858 - val_mean_absolute_error: 1.5249 - 6s/epoch - 6ms/step
# Epoch 98/100
# 1001/1001 - 7s - loss: 4.5657 - mean_squared_error: 4.5657 - mean_absolute_error: 1.4659 - val_loss: 5.0312 - val_mean_squared_error: 5.0312 - val_mean_absolute_error: 1.5838 - 7s/epoch - 7ms/step
# Epoch 99/100
# 1001/1001 - 7s - loss: 4.3592 - mean_squared_error: 4.3592 - mean_absolute_error: 1.4202 - val_loss: 4.2972 - val_mean_squared_error: 4.2972 - val_mean_absolute_error: 1.3897 - 7s/epoch - 7ms/step
# Epoch 100/100
# 1001/1001 - 7s - loss: 4.3332 - mean_squared_error: 4.3332 - mean_absolute_error: 1.4146 - val_loss: 4.3595 - val_mean_squared_error: 4.3595 - val_mean_absolute_error: 1.4076 - 7s/epoch - 7ms/step

# %% [markdown]
# ##### Step 4 - Plot loss over epochs

# %%
# Gather the trained model's weight and bias.
trained_weight = model2.get_weights()[0]
trained_bias = model2.get_weights()[1]

  # The list of epochs is stored separately from the 
  # rest of history.
epochs = history.epoch
  
  # Gather the history (a snapshot) of each epoch.
#hist = pd.DataFrame(history.history)

  # Specifically gather the model's root mean 
  # squared error at each epoch. 
mse = history.history["mean_squared_error"]

#plot_the_model(trained_weight, trained_bias, X_test, Y_train)
plot_the_loss_curve(epochs, mse)

# %% [markdown]
# ##### Step 5 - Print Performance Summary

# %%
print("")
print('-------------------- Model Summary --------------------')
model2.summary() # print model summary
print("")
print('-------------------- Weights and Biases --------------------')
print("Too many parameters to print but you can use the code provided if needed")
print("")
#for layer in model.layers:
#    print(layer.name)
#    for item in layer.get_weights():
#        print("  ", item)
#print("")

# Print the last value in the evaluation metrics contained within history file
print('-------------------- Evaluation on Training Data --------------------')
for item in history.history:
    print("Final", item, ":", history.history[item][-1])
print("")

# Evaluate the model on the test data using "evaluate"
print('-------------------- Evaluation on Test Data --------------------')
results = model2.evaluate(X_test, Y_test)
print("")
# Out:
# -------------------- Model Summary --------------------
# Model: "biLSTM-Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 10, 64)            17408
#
#  Output-Layer (TimeDistribut  (None, 10, 1)            65
#  ed)
#
# =================================================================
# Total params: 17,473
# Trainable params: 17,473
# Non-trainable params: 0
# _________________________________________________________________
#
# -------------------- Weights and Biases --------------------
# Too many parameters to print but you can use the code provided if needed
#
# -------------------- Evaluation on Training Data --------------------
# Final loss : 4.333169460296631
# Final mean_squared_error : 4.333168983459473
# Final mean_absolute_error : 1.4146037101745605
# Final val_loss : 4.35948371887207
# Final val_mean_squared_error : 4.359484672546387
# Final val_mean_absolute_error : 1.4075764417648315
#
# -------------------- Evaluation on Test Data --------------------
# 484/484 [==============================] - 2s 3ms/step - loss: 11.8463 - mean_squared_error: 11.8463 - mean_absolute_error: 2.1073

# %%
results
# loss: 9.2961 - mean_squared_error: 9.2960 normalize 01  loss: 8.9703 - mean_squared_error: 8.9703 - accuracy: 0.0000e+00
# Out:
# [11.846274375915527, 11.846273422241211, 2.107304811477661]

# %%
from keras.utils import plot_model,model_to_dot
plot_model(model2, show_shapes=True, to_file='plotmodelbilstm0810.png')

# %%
pred_test=model2.predict(X_test)
# Out:
# 484/484 [==============================] - 2s 3ms/step

# %%
Y_test.shape
#1792
# Out:
# (15470, 10, 1)

# %%
test.values.size
# Out:
# 18700

# %%
pred_test.shape
# Out:
# (15470, 10, 1)

# %%
# pred_test = scaler2.inverse_transform(pred_test.reshape(-1, pred_test.shape[-1])).reshape(pred_test.shape)
y=pred_test.flatten()
# y=scaler2.inverse_transform(y.reshape(-1,y.shape[-1])).reshape(y.shape)
z=[]
for x in range(910*95,910*96,10): #predictioon
    z.append(y[x])
z

b=Y_test.flatten() #Y test should match prediction
# b=scaler2.inverse_transform(b.reshape(-1,b.shape[-1])).reshape(b.shape)
c=[] #wtf is this
for x in range(910*95,910*96,10):
    c.append(b[x])
#c

# d=X_test.flatten() # Y train doesnt match because why
# e=[]
# for x in range(0,10000,1):
#     if(d[x]==0):
#         print(x)
#     e.append(d[x])
# # e

# %%
# Plot (actual and predicted) for test (out of time) data
fig = go.Figure()

# #Trace for actual val
# fig.add_trace(go.Scatter(x=np.array(test.columns),
#                          y=np.array(test.values).flatten(),
#                          mode='lines',
#                          name='Subsidence - Actual (Test)',
#                          opacity=0.8,
#                          line=dict(color='black', width=1)
#                         ))
# fig.add_trace(go.Scatter(x=np.array(test.columns),
#                          y=e,
#                          mode='lines',
#                          name='Subsidence - Actual (YTrain)',
#                          opacity=0.8,
#                          line=dict(color='pink', width=1)
#                         ))

fig.add_trace(go.Scatter(x=np.array(test.columns[10:]),
                         y=c,
                         mode='lines',
                         name='Subsidence - Actual (YTest)',
                         opacity=0.8,
                         line=dict(color='grey', width=5)
                        ))


# Trace for predicted 
fig.add_trace(go.Scatter(x=np.array(test.columns[10:]),
                         y=z,
                         mode='lines',
                         name='Subsidence - Predicted ',
                         opacity=0.8,
                         line=dict(color='red', width=5)
                        ))

# Change chart background color
fig.update_layout(dict(plot_bgcolor = 'white'))

# Update axes lines
fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='lightgrey', 
                 zeroline=True, zerolinewidth=1, zerolinecolor='lightgrey', 
                 showline=True, linewidth=1, linecolor='black',
                 title='Month-Year'
                )

fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='lightgrey', 
                 zeroline=True, zerolinewidth=1, zerolinecolor='lightgrey', 
                 showline=True, linewidth=1, linecolor='black',
                 title='Subsidence'
                )

# Set figure title
fig.update_layout(title=dict(text="Subsidence", font=dict(color='black')),
                  legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1)
                 )
fig.show()
