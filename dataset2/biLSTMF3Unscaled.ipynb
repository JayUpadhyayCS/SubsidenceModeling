# %%
# Tensorflow / Keras
from tensorflow import keras # for building Neural Networks
print('Tensorflow/Keras: %s' % keras.__version__) # print version
from keras.models import Sequential # for creating a linear stack of layers for our Neural Network
from keras import Input # for instantiating a keras tensor
from keras.layers import Masking,Bidirectional, LSTM, RepeatVector, Dense, TimeDistributed,MaxPooling1D, Flatten, Conv1D,Conv2D,Dropout, MaxPooling2D, GRU # for creating layers inside the Neural Network
from keras.optimizers import Adam , SGD
from keras import metrics, callbacks
from keras.utils import plot_model
# Data manipulation
import pandas as pd # for data manipulation
print('pandas: %s' % pd.__version__) # print version
import numpy as np # for data manipulation
print('numpy: %s' % np.__version__) # print version
import numpy.ma as ma
# Sklearn
import sklearn
print('sklearn: %s' % sklearn.__version__) # print version
from sklearn.preprocessing import MinMaxScaler, StandardScaler # for feature scaling
from sklearn.model_selection import train_test_split
# Visualization
import plotly 
import plotly.express as px
import plotly.graph_objects as go
print('plotly: %s' % plotly.__version__) # print version
from matplotlib import pyplot as plt

#file accessing
import os
# time stuff
from datetime import timedelta
import calendar
# Out:
# Tensorflow/Keras: 2.9.0
# pandas: 1.4.2
# numpy: 1.22.4
# sklearn: 1.1.1
# plotly: 5.9.0

# %%
#@title Define the plotting functions
def plot_the_model(trained_weight, trained_bias, feature, label):
  """Plot the trained model against the training feature and label."""

  # Label the axes.
  plt.xlabel("feature")
  plt.ylabel("label")

  # Plot the feature values vs. label values.
  plt.scatter(feature, label)

  # Create a red line representing the model. The red line starts
  # at coordinates (x0, y0) and ends at coordinates (x1, y1).
  x0 = 0
  y0 = trained_bias
  x1 = feature[-1]
  y1 = trained_bias + (trained_weight * x1)
  plt.plot([x0, x1], [y0, y1], c='r')

  # Render the scatter plot and the red line.
  plt.show()

def plot_the_loss_curve(epochs, mse):
  """Plot the loss curve, which shows loss vs. epoch."""

  plt.figure()
  plt.xlabel("Epoch")
  plt.ylabel("Mean Squared Error")
  #epochs.remove(max(epochs))
  
  #rmse.drop(max(rmse))
  plt.plot(epochs, mse, label="Loss")
  plt.legend()
  plt.ylim([min(mse)*0.97, max(mse)])
  plt.show()

print("Defined the plot_the_model and plot_the_loss_curve functions.")
# Out:
# Defined the plot_the_model and plot_the_loss_curve functions.

# %% [markdown]
# ##### Read from file and establish dataframe and future functions

# %%
df=pd.read_csv('E:\DSFellowship\Complete\dataset2\dataset2.csv')
df=df.set_index([df.columns[0],df.columns[1]])
df.columns=pd.to_datetime(df.columns, format='%Y-%m-%d')
df=df.dropna(axis=0, how='all')#drop full nan rows
df
# Out:
#                     2014-11-08  2014-12-02  2014-12-26  2015-02-12  \
# Longitude Latitude
# -120.3387 36.5393          0.0     -6.2129      3.4247      5.7830
# -120.1908 36.1412          0.0     -5.6951      2.2257      4.5835
# -119.8869 35.6171          0.0     -6.7674      1.8611      3.5773
# -119.8849 35.8671          0.0     -6.9006      1.5378      3.1628
# -119.8829 35.9512          0.0     -6.3572      1.1703      2.1735
# ...                        ...         ...         ...         ...
# -118.9071 35.3750          0.0     -3.8828     -1.1999     -1.2152
# -118.9051 35.3430          0.0     -4.1356     -1.1255     -1.2232
# -118.9031 35.3110          0.0     -4.1879     -1.1213     -1.7977
#           35.4270          0.0     -4.1305     -1.2911     -1.1049
# -118.9011 35.3950          0.0     -4.1354     -1.3291     -1.1547
#
#                     2015-03-08  2015-04-01  2015-04-25  2015-05-19  \
# Longitude Latitude
# -120.3387 36.5393      2.13990      6.8538     1.83540      2.1142
# -120.1908 36.1412      1.70790      6.5348     2.98530      2.7613
# -119.8869 35.6171      0.77856      4.5700     1.90460      2.8225
# -119.8849 35.8671      0.49591      5.3001     1.69690      2.4262
# -119.8829 35.9512     -0.47235      3.9732     0.57705      1.4311
# ...                        ...         ...         ...         ...
# -118.9071 35.3750     -2.12550     -3.4199    -0.94401     -3.6226
# -118.9051 35.3430     -2.18530     -3.3244    -0.70324     -3.5807
# -118.9031 35.3110     -2.28030     -3.4793    -0.84339     -3.6445
#           35.4270     -2.53270     -3.4353    -0.79675     -3.7570
# -118.9011 35.3950     -2.29250     -3.5912    -0.82694     -3.6488
#
#                     2015-06-12  2015-07-06  ...  2018-10-18  2018-10-30  \
# Longitude Latitude                          ...
# -120.3387 36.5393      1.83670     -1.5935  ...     4.93520    8.059200
# -120.1908 36.1412      3.76730      2.2235  ...     6.28560    8.606700
# -119.8869 35.6171      0.89615      2.6578  ...     6.42140    7.527900
# -119.8849 35.8671      1.60660      1.9497  ...     6.71270    8.195900
# -119.8829 35.9512      0.69616      1.1763  ...     5.86560    7.390000
# ...                        ...         ...  ...         ...         ...
# -118.9071 35.3750      0.56910     -1.4506  ...     2.44230    2.689300
# -118.9051 35.3430      0.53279     -1.5025  ...     1.45350    1.393300
# -118.9031 35.3110      0.30264     -2.1569  ...    -0.17429    0.098737
#           35.4270      0.58227     -1.2981  ...     3.02090    3.222600
# -118.9011 35.3950      0.71169     -1.0560  ...     2.84470    3.160200
#
#                     2018-11-11  2018-11-17  2018-11-23  2018-12-05  \
# Longitude Latitude
# -120.3387 36.5393      6.39190     6.56470     3.58430    5.337900
# -120.1908 36.1412      7.15330     8.06940     5.60730    4.977600
# -119.8869 35.6171      6.25500     7.12750     7.43410    3.680000
# -119.8849 35.8671      6.89780     7.72280     7.08070    5.015800
# -119.8829 35.9512      6.27260     7.15710     5.54560    3.736800
# ...                        ...         ...         ...         ...
# -118.9071 35.3750      3.37490     3.22130     3.32230    2.285500
# -118.9051 35.3430      2.12930     1.83520     2.14240    1.547400
# -118.9031 35.3110      0.56824     0.16814     0.69418   -0.011814
#           35.4270      4.33210     3.71760     4.08800    2.244900
# -118.9011 35.3950      4.13480     3.61790     3.82230    2.624100
#
#                     2018-12-17  2018-12-29  2019-01-10  2019-01-22
# Longitude Latitude
# -120.3387 36.5393      7.14430      9.1285     8.73970    10.38400
# -120.1908 36.1412      8.18450      9.0591     8.89620    10.35300
# -119.8869 35.6171      6.77130      8.8868     7.87950     9.15160
# -119.8849 35.8671      6.95200      8.8647     8.17390     9.19100
# -119.8829 35.9512      6.18420      7.5924     6.51850     8.10940
# ...                        ...         ...         ...         ...
# -118.9071 35.3750      1.94290      5.8860     2.26160     2.42750
# -118.9051 35.3430      1.06060      4.7605     0.96871     1.18650
# -118.9031 35.3110     -0.57993      2.7450    -1.03220    -0.71361
#           35.4270      2.98550      6.4669     2.77250     2.71350
# -118.9011 35.3950      2.65560      6.3724     2.70740     2.72110
#
# [603 rows x 110 columns]

# %%
dfgw=pd.read_csv('E:\DSFellowship\InSAR_data_south/displacement/groundwater.csv')
dfgw=dfgw.set_index([dfgw.columns[0],dfgw.columns[1]])
dfgw.columns=pd.to_datetime(dfgw.columns, format='%Y-%m-%d')
dfgw=dfgw.dropna(axis=0, how='all')#drop full nan rows
for y in range(df.columns.size):# includes all dates and adds nans
    if df.columns[y] != dfgw.columns[y]: #if column is misssing insert it
        dfgw.insert(loc=y,column=df.columns[y],value=np.nan*237,allow_duplicates=False)

# %%
for x in range(len(dfgw.index)):
    dfgw.iloc[x]=dfgw.iloc[x].fillna(method='ffill')
    dfgw.iloc[x]=dfgw.iloc[x].fillna(method='bfill')
    
dfgw
# Out:
#                     2014-11-08  2014-12-02  2014-12-26  2015-02-12  \
# Longitude Latitude
# -120.9486 37.6316    81.000000   81.000000   81.000000   81.000000
# -120.8926 36.7114    72.248964   72.248964   72.248964   72.248964
# -120.8846 36.6994    72.248964   72.248964   72.248964   72.248964
# -120.8746 36.6874    72.248964   72.248964   72.248964   72.248964
# -120.1368 35.6991   141.123387  141.123387  141.123387  141.123387
# ...                        ...         ...         ...         ...
# -119.0351 36.3933    17.409091   17.409091   17.409091   17.409091
# -119.0271 36.3793    17.409091   17.409091   17.409091   17.409091
# -119.0571 36.4493    17.409091   17.409091   17.409091   17.409091
# -119.0211 36.3993    17.409091   17.409091   17.409091   17.409091
# -119.0111 36.3873    17.409091   17.409091   17.409091   17.409091
#
#                     2015-03-08  2015-04-01  2015-04-25  2015-05-19  \
# Longitude Latitude
# -120.9486 37.6316    81.000000   81.000000   81.000000   81.000000
# -120.8926 36.7114    72.248964   72.248964   72.248964   72.248964
# -120.8846 36.6994    72.248964   72.248964   72.248964   72.248964
# -120.8746 36.6874    72.248964   72.248964   72.248964   72.248964
# -120.1368 35.6991   141.123387  141.123387  141.123387  141.123387
# ...                        ...         ...         ...         ...
# -119.0351 36.3933    17.409091   17.409091   17.409091   17.409091
# -119.0271 36.3793    17.409091   17.409091   17.409091   17.409091
# -119.0571 36.4493    17.409091   17.409091   17.409091   17.409091
# -119.0211 36.3993    17.409091   17.409091   17.409091   17.409091
# -119.0111 36.3873    17.409091   17.409091   17.409091   17.409091
#
#                     2015-06-12  2015-07-06  ...  2018-10-18  2018-10-30  \
# Longitude Latitude                          ...
# -120.9486 37.6316    81.000000   81.000000  ...   75.653992   75.813688
# -120.8926 36.7114    72.248964   72.248964  ...   75.200000   75.200000
# -120.8846 36.6994    72.248964   72.248964  ...   75.200000   75.200000
# -120.8746 36.6874    72.248964   72.248964  ...   75.200000   75.200000
# -120.1368 35.6991   141.123387  141.123387  ...  150.898190  151.000000
# ...                        ...         ...  ...         ...         ...
# -119.0351 36.3933    17.409091   17.409091  ...   16.978182   17.000000
# -119.0271 36.3793    17.409091   17.409091  ...   16.978182   17.000000
# -119.0571 36.4493    17.409091   17.409091  ...   16.978182   17.000000
# -119.0211 36.3993    17.409091   17.409091  ...   16.978182   17.000000
# -119.0111 36.3873    17.409091   17.409091  ...   16.978182   17.000000
#
#                     2018-11-11  2018-11-17  2018-11-23  2018-12-05  \
# Longitude Latitude
# -120.9486 37.6316    75.973384        76.0        76.0        76.0
# -120.8926 36.7114    75.200000        75.2        75.2        75.2
# -120.8846 36.6994    75.200000        75.2        75.2        75.2
# -120.8746 36.6874    75.200000        75.2        75.2        75.2
# -120.1368 35.6991   151.000000       151.0       151.0       151.0
# ...                        ...         ...         ...         ...
# -119.0351 36.3933    17.000000        17.0        17.0        17.0
# -119.0271 36.3793    17.000000        17.0        17.0        17.0
# -119.0571 36.4493    17.000000        17.0        17.0        17.0
# -119.0211 36.3993    17.000000        17.0        17.0        17.0
# -119.0111 36.3873    17.000000        17.0        17.0        17.0
#
#                     2018-12-17  2018-12-29  2019-01-10  2019-01-22
# Longitude Latitude
# -120.9486 37.6316         76.0        76.0        76.0        76.0
# -120.8926 36.7114         75.2        75.2        75.2        75.2
# -120.8846 36.6994         75.2        75.2        75.2        75.2
# -120.8746 36.6874         75.2        75.2        75.2        75.2
# -120.1368 35.6991        151.0       151.0       151.0       151.0
# ...                        ...         ...         ...         ...
# -119.0351 36.3933         17.0        17.0        17.0        17.0
# -119.0271 36.3793         17.0        17.0        17.0        17.0
# -119.0571 36.4493         17.0        17.0        17.0        17.0
# -119.0211 36.3993         17.0        17.0        17.0        17.0
# -119.0111 36.3873         17.0        17.0        17.0        17.0
#
# [11286 rows x 110 columns]

# %%
drain=pd.read_csv('E:\DSFellowship\InSAR_data_south/displacement/rainfall.csv')
drain=drain.set_index([drain.columns[0],drain.columns[1]])
drain.columns=pd.to_datetime(drain.columns, format='%Y-%m-%d')
for y in range(df.columns.size):# includes all dates and adds nans
    if df.columns[y] != drain.columns[y]: #if column is misssing insert it
        drain.insert(loc=y,column=df.columns[y],value=np.nan*237,allow_duplicates=False)
drain
# Out:
# C:\Users\jupad\AppData\Local\Temp\ipykernel_24084\1991105724.py:6: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#                     2014-11-08  2014-12-02  2014-12-26  2015-02-12  \
# Longitude Latitude
# -120.9486 37.6316          NaN         NaN         NaN         NaN
# -120.8926 36.7114          NaN         NaN         NaN         NaN
# -120.8846 36.6994          NaN         NaN         NaN         NaN
# -120.8746 36.6874          NaN         NaN         NaN         NaN
# -120.1368 35.6991          NaN         NaN         NaN         NaN
# ...                        ...         ...         ...         ...
# -119.0351 36.3933          NaN         NaN         NaN         NaN
# -119.0271 36.3793          NaN         NaN         NaN         NaN
# -119.0571 36.4493          NaN         NaN         NaN         NaN
# -119.0211 36.3993          NaN         NaN         NaN         NaN
# -119.0111 36.3873          NaN         NaN         NaN         NaN
#
#                     2015-03-08  2015-04-01  2015-04-25  2015-05-19  \
# Longitude Latitude
# -120.9486 37.6316          NaN         NaN         NaN         NaN
# -120.8926 36.7114          NaN         NaN         NaN         NaN
# -120.8846 36.6994          NaN         NaN         NaN         NaN
# -120.8746 36.6874          NaN         NaN         NaN         NaN
# -120.1368 35.6991          NaN         NaN         NaN         NaN
# ...                        ...         ...         ...         ...
# -119.0351 36.3933          NaN         NaN         NaN         NaN
# -119.0271 36.3793          NaN         NaN         NaN         NaN
# -119.0571 36.4493          NaN         NaN         NaN         NaN
# -119.0211 36.3993          NaN         NaN         NaN         NaN
# -119.0111 36.3873          NaN         NaN         NaN         NaN
#
#                     2015-06-12  2015-07-06  ...    2018-10-18    2018-10-30  \
# Longitude Latitude                          ...
# -120.9486 37.6316          NaN         NaN  ...  1.002529e-08  5.244156e-15
# -120.8926 36.7114          NaN         NaN  ...  0.000000e+00  0.000000e+00
# -120.8846 36.6994          NaN         NaN  ...  0.000000e+00  0.000000e+00
# -120.8746 36.6874          NaN         NaN  ...  0.000000e+00  0.000000e+00
# -120.1368 35.6991          NaN         NaN  ...  3.111030e-01  1.693514e-02
# ...                        ...         ...  ...           ...           ...
# -119.0351 36.3933          NaN         NaN  ...  5.021634e+00  0.000000e+00
# -119.0271 36.3793          NaN         NaN  ...  5.355278e+00  0.000000e+00
# -119.0571 36.4493          NaN         NaN  ...  4.488359e+00  2.814860e-11
# -119.0211 36.3993          NaN         NaN  ...  5.280554e+00  0.000000e+00
# -119.0111 36.3873          NaN         NaN  ...  5.355278e+00  0.000000e+00
#
#                       2018-11-11  2018-11-17  2018-11-23  2018-12-05  \
# Longitude Latitude
# -120.9486 37.6316   3.241600e-13         0.0   19.307816   64.067047
# -120.8926 36.7114   0.000000e+00         0.0   10.529937   41.590660
# -120.8846 36.6994   0.000000e+00         0.0   10.653009   42.319168
# -120.8746 36.6874   0.000000e+00         0.0   10.783698   43.095787
# -120.1368 35.6991   1.218172e+00         0.0   33.671449  152.541073
# ...                          ...         ...         ...         ...
# -119.0351 36.3933   2.206239e-07         0.0   37.236885  134.395294
# -119.0271 36.3793   5.527269e-09         0.0   37.965350  138.551914
# -119.0571 36.4493   0.000000e+00         0.0   37.284857  126.509520
# -119.0211 36.3993   9.966460e-08         0.0   37.817726  137.682442
# -119.0111 36.3873   5.527269e-09         0.0   37.965350  138.551914
#
#                     2018-12-17  2018-12-29  2019-01-10  2019-01-22
# Longitude Latitude
# -120.9486 37.6316    31.963058   25.633082   28.319157   59.736828
# -120.8926 36.7114    20.704192   29.202840   14.592794   11.388287
# -120.8846 36.6994    20.722277   29.526450   14.602126   11.487171
# -120.8746 36.6874    20.731019   29.834099   14.613811   11.625130
# -120.1368 35.6991    14.180448   23.243916   62.997394  122.872945
# ...                        ...         ...         ...         ...
# -119.0351 36.3933     8.690165   34.406051   84.547653  165.973335
# -119.0271 36.3793    10.061119   37.785093   91.544703  176.264024
# -119.0571 36.4493     4.650238   25.860381   65.558802  137.376688
# -119.0211 36.3993     9.743326   37.013587   89.856909  173.824250
# -119.0111 36.3873    10.061119   37.785093   91.544703  176.264024
#
# [11286 rows x 110 columns]

# %%
drain=drain.transpose()
for x in drain.columns.values:
    drain[x].fillna(drain[x].mean(),inplace=True)
drain=drain.transpose()
drain
# Out:
#                     2014-11-08  2014-12-02  2014-12-26  2015-02-12  \
# Longitude Latitude
# -120.9486 37.6316    14.100342   14.100342   14.100342   14.100342
# -120.8926 36.7114    10.444028   10.444028   10.444028   10.444028
# -120.8846 36.6994    10.456846   10.456846   10.456846   10.456846
# -120.8746 36.6874    10.468676   10.468676   10.468676   10.468676
# -120.1368 35.6991    39.903783   39.903783   39.903783   39.903783
# ...                        ...         ...         ...         ...
# -119.0351 36.3933    45.279917   45.279917   45.279917   45.279917
# -119.0271 36.3793    48.352180   48.352180   48.352180   48.352180
# -119.0571 36.4493    36.942623   36.942623   36.942623   36.942623
# -119.0211 36.3993    47.630206   47.630206   47.630206   47.630206
# -119.0111 36.3873    48.352180   48.352180   48.352180   48.352180
#
#                     2015-03-08  2015-04-01  2015-04-25  2015-05-19  \
# Longitude Latitude
# -120.9486 37.6316    14.100342   14.100342   14.100342   14.100342
# -120.8926 36.7114    10.444028   10.444028   10.444028   10.444028
# -120.8846 36.6994    10.456846   10.456846   10.456846   10.456846
# -120.8746 36.6874    10.468676   10.468676   10.468676   10.468676
# -120.1368 35.6991    39.903783   39.903783   39.903783   39.903783
# ...                        ...         ...         ...         ...
# -119.0351 36.3933    45.279917   45.279917   45.279917   45.279917
# -119.0271 36.3793    48.352180   48.352180   48.352180   48.352180
# -119.0571 36.4493    36.942623   36.942623   36.942623   36.942623
# -119.0211 36.3993    47.630206   47.630206   47.630206   47.630206
# -119.0111 36.3873    48.352180   48.352180   48.352180   48.352180
#
#                     2015-06-12  2015-07-06  ...    2018-10-18    2018-10-30  \
# Longitude Latitude                          ...
# -120.9486 37.6316    14.100342   14.100342  ...  1.002529e-08  5.244156e-15
# -120.8926 36.7114    10.444028   10.444028  ...  0.000000e+00  0.000000e+00
# -120.8846 36.6994    10.456846   10.456846  ...  0.000000e+00  0.000000e+00
# -120.8746 36.6874    10.468676   10.468676  ...  0.000000e+00  0.000000e+00
# -120.1368 35.6991    39.903783   39.903783  ...  3.111030e-01  1.693514e-02
# ...                        ...         ...  ...           ...           ...
# -119.0351 36.3933    45.279917   45.279917  ...  5.021634e+00  0.000000e+00
# -119.0271 36.3793    48.352180   48.352180  ...  5.355278e+00  0.000000e+00
# -119.0571 36.4493    36.942623   36.942623  ...  4.488359e+00  2.814860e-11
# -119.0211 36.3993    47.630206   47.630206  ...  5.280554e+00  0.000000e+00
# -119.0111 36.3873    48.352180   48.352180  ...  5.355278e+00  0.000000e+00
#
#                       2018-11-11  2018-11-17  2018-11-23  2018-12-05  \
# Longitude Latitude
# -120.9486 37.6316   3.241600e-13         0.0   19.307816   64.067047
# -120.8926 36.7114   0.000000e+00         0.0   10.529937   41.590660
# -120.8846 36.6994   0.000000e+00         0.0   10.653009   42.319168
# -120.8746 36.6874   0.000000e+00         0.0   10.783698   43.095787
# -120.1368 35.6991   1.218172e+00         0.0   33.671449  152.541073
# ...                          ...         ...         ...         ...
# -119.0351 36.3933   2.206239e-07         0.0   37.236885  134.395294
# -119.0271 36.3793   5.527269e-09         0.0   37.965350  138.551914
# -119.0571 36.4493   0.000000e+00         0.0   37.284857  126.509520
# -119.0211 36.3993   9.966460e-08         0.0   37.817726  137.682442
# -119.0111 36.3873   5.527269e-09         0.0   37.965350  138.551914
#
#                     2018-12-17  2018-12-29  2019-01-10  2019-01-22
# Longitude Latitude
# -120.9486 37.6316    31.963058   25.633082   28.319157   59.736828
# -120.8926 36.7114    20.704192   29.202840   14.592794   11.388287
# -120.8846 36.6994    20.722277   29.526450   14.602126   11.487171
# -120.8746 36.6874    20.731019   29.834099   14.613811   11.625130
# -120.1368 35.6991    14.180448   23.243916   62.997394  122.872945
# ...                        ...         ...         ...         ...
# -119.0351 36.3933     8.690165   34.406051   84.547653  165.973335
# -119.0271 36.3793    10.061119   37.785093   91.544703  176.264024
# -119.0571 36.4493     4.650238   25.860381   65.558802  137.376688
# -119.0211 36.3993     9.743326   37.013587   89.856909  173.824250
# -119.0111 36.3873    10.061119   37.785093   91.544703  176.264024
#
# [11286 rows x 110 columns]

# %% [markdown]
# ##### Remove next line to include all data

# %% [markdown]
# # Timestep

# %%
timestep=10
# 1 2 3 4 5 6 7 ...
# w/ timestep of 2
# [[1,2][2,3][3,4]

# %% [markdown]
# # Shaping function (remove start and step for first for loop to include all data)

# %%
def shaping3(datain,datain2,datain3 ,timestep, features):
    #print(arr)
    cnt=0
    for row in range(len(datain.index)): #picks a row at every iteration, allows to reduction of input and inclusion of multiple time series, remove start and step to run on full dataset 
    # Convert input dataframe to array and flatten

        # if datain.index[row] not in datain2.index:
        #     #print("Not found", cnt)
        #     continue
        
        #arr1=scaler.fit_transform(datain2.loc[datain.index[row]].to_numpy().flatten().reshape(-1,datain2.loc[datain.index[row]].shape[-1])).reshape(datain2.loc[datain.index[row]].shape)
        #arr2=scaler.fit_transform(datain3.loc[datain.index[row]].to_numpy().flatten().reshape(-1,datain3.loc[datain.index[row]].shape[-1])).reshape(datain3.loc[datain.index[row]].shape)
        
        arr1=datain2.loc[datain.index[row]].to_numpy().flatten()
        arr2=datain3.loc[datain.index[row]].to_numpy().flatten()
        arr=datain.iloc[row].interpolate().to_numpy().flatten()
        #arr=scaler.fit_transform(arr.reshape(-1,arr.shape[-1])).reshape(arr.shape)

        # arr1=datain3.loc[datain.index[row]].to_numpy().flatten()
        # # print("found", row)
        # arr2=datain2.loc[datain.index[row]].to_numpy().flatten() # rainfall
         
        
        #arr2=np.where(np.isnan(arr2), ma.array(arr2, mask=np.isnan(arr2)).mean(), arr2) 
        arr3=np.concatenate((arr,arr2,arr1)).reshape(features,110)
        
        
        for mth in range(0, len(datain2.columns)-(2*timestep)+1): # Define range lenght of the dates - 2* amount of timesep?? +1
            cnt=cnt+1 # Gives us the number of samples. Later used to reshape the data
            X_start=mth # Start month for inputs of each sample
            X_end=mth+timestep # End month for inputs of each sample
            Y_start=mth+timestep # Start month for targets of each sample. Note, start is inclusive and end is exclusive, that's why X_end and Y_start is the same number
            Y_end=mth+2*timestep # End month for targets of each sample.  
            
            # Assemble input and target arrays containing all samples
            if cnt==1:
                X_comb=arr3[:,X_start:X_end]
                #arr3=scaler.inverse_transform(arr3.reshape(-1,arr3.shape[-1])).reshape(arr3.shape)
                Y_comb=arr3[0][Y_start:Y_end]
            else: 
                X_comb=np.append(X_comb, arr3[:,X_start:X_end])
                #arr3=scaler.inverse_transform(arr3.reshape(-1,arr3.shape[-1])).reshape(arr3.shape)
                Y_comb=np.append(Y_comb, arr3[:1,Y_start:Y_end])
    
    # Reshape input and target arrays
    X_out=np.reshape(X_comb, (cnt, timestep, features))
    Y_out=np.reshape(Y_comb, (cnt, timestep, 1))
    return X_out, Y_out

# %% [markdown]
# ##### Step 2 - Split and Shape data

# %%
#Divides data into 80% training 20% testing
#train, test = train_test_split(df, test_size=0.2)
# creates sequences to train
# X , Y = shaping(datain=df, timestep= timestep )
# X_train, X_test, Y_train, Y_test = train_test_split(X,Y , test_size=0.2, random_state=28)
# nsamples, nx, ny = X_train.shape
# X_train = X_train.reshape((nsamples,nx*ny))
# nsamples, nx, ny = Y_train.shape
# Y_train = Y_train.reshape((nsamples,nx*ny))
# nsamples, nx, ny = X_test.shape
# X_test = X_test.reshape((nsamples,nx*ny))
# nsamples, nx, ny = Y_test.shape
# Y_test = Y_test.reshape((nsamples,nx*ny))
#Divides data into 80% training 20% testing
features=3


train, test=train_test_split(df,test_size=.2,shuffle=True,random_state=42)
X_train, Y_train = shaping3(datain=train,datain2=drain,datain3=dfgw, timestep= timestep,features=features )



X_test, Y_test = shaping3(datain=test,datain2=drain,datain3=dfgw, timestep= timestep,features=features )

# %%
# scaler = MinMaxScaler()
# scaler2 = MinMaxScaler()
# X_train = scaler.fit_transform(X_train.reshape(-1, X_train.shape[-1])).reshape(X_train.shape)
# X_test = scaler.transform(X_test.reshape(-1, X_test.shape[-1])).reshape(X_test.shape)
# Y_train = scaler2.fit_transform(Y_train.reshape(-1, Y_train.shape[-1])).reshape(Y_train.shape)
# Y_test = scaler2.transform(Y_test.reshape(-1, Y_test.shape[-1])).reshape(Y_test.shape)

# %% [markdown]
# ##### Step 3 - Specify the structure of a Neural Network, first model

# %%
callback = callbacks.EarlyStopping(monitor='loss', patience=3)
model2 = Sequential(name="biLSTM-Model") # Model
#model2.add(Masking(mask_value=-1000, input_shape=(timestep, 1)))

model2.add(Input(shape=(X_train.shape[1],X_train.shape[2]), name='Input-Layer')) # Input Layer - need to speicfy the shape of inputs
model2.add(Bidirectional(LSTM(units=64, activation='relu', recurrent_activation='sigmoid', stateful=False), name='Hidden-LSTM-Encoder-Layer')) # Encoder Layer
model2.add(RepeatVector(Y_train.shape[1], name='Repeat-Vector-Layer')) # Repeat Vector
model2.add(Bidirectional(LSTM(units=64, activation='relu', recurrent_activation='sigmoid', stateful=False, return_sequences=True), name='Hidden-LSTM-Decoder-Layer')) # Decoder Layer
model2.add(TimeDistributed(Dense(units=1, activation='linear'), name='Output-Layer')) # Output Layer, Linear(x) = x
#optimizer=Adam(.005)
model2.compile(optimizer='adam', # default='rmsprop', an algorithm to be used in backpropagation
              loss='mean_squared_error', # Loss function to be optimized. A string (name of loss function), or a tf.keras.losses.Loss instance.
                metrics=['MeanSquaredError', 'mean_absolute_error'], # List of metrics to be evaluated by the model during training and testing. Each of this can be a string (name of a built-in function), function or a tf.keras.metrics.Metric instance. 
              loss_weights=None, # default=None, Optional list or dictionary specifying scalar coefficients (Python floats) to weight the loss contributions of different model outputs.
              weighted_metrics=None, # default=None, List of metrics to be evaluated and weighted by sample_weight or class_weight during training and testing.
              run_eagerly=None, # Defaults to False. If True, this Model's logic will not be wrapped in a tf.function. Recommended to leave this as None unless your Model cannot be run inside a tf.function.
              steps_per_execution=None, # Defaults to 1. The number of batches to run during each tf.function call. Running multiple batches inside a single tf.function call can greatly improve performance on TPUs or small models with a large Python overhead.
                   
             )

# %%
##### Train model

# %%
history = model2.fit(X_train, # input data
                    Y_train, # target data
                    batch_size=32, # Number of samples per gradient update. If unspecified, batch_size will default to 32.
                    epochs=100, # default=1, Number of epochs to train the model. An epoch is an iteration over the entire x and y data provided
                    verbose=2, # default='auto', ('auto', 0, 1, or 2). Verbosity mode. 0 = silent, 1 = progress bar, 2 = one line per epoch. 'auto' defaults to 1 for most cases, but 2 when used with ParameterServerStrategy.
                    callbacks=None, # default=None, list of callbacks to apply during training. See tf.keras.callbacks
                    validation_split=0.25, # default=0.0, Fraction of the training data to be used as validation data. The model will set apart this fraction of the training data, will not train on it, and will evaluate the loss and any model metrics on this data at the end of each epoch. 
                    #validation_data=(X_test, y_test), # default=None, Data on which to evaluate the loss and any model metrics at the end of each epoch. 
                    shuffle=True, # default=True, Boolean (whether to shuffle the training data before each epoch) or str (for 'batch').
                    class_weight=None, # default=None, Optional dictionary mapping class indices (integers) to a weight (float) value, used for weighting the loss function (during training only). This can be useful to tell the model to "pay more attention" to samples from an under-represented class.
                    sample_weight=None, # default=None, Optional Numpy array of weights for the training samples, used for weighting the loss function (during training only).
                    initial_epoch=0, # Integer, default=0, Epoch at which to start training (useful for resuming a previous training run).
                    steps_per_epoch=None, # Integer or None, default=None, Total number of steps (batches of samples) before declaring one epoch finished and starting the next epoch. When training with input tensors such as TensorFlow data tensors, the default None is equal to the number of samples in your dataset divided by the batch size, or 1 if that cannot be determined. 
                    validation_steps=None, # Only relevant if validation_data is provided and is a tf.data dataset. Total number of steps (batches of samples) to draw before stopping when performing validation at the end of every epoch.
                    validation_batch_size=None, # Integer or None, default=None, Number of samples per validation batch. If unspecified, will default to batch_size.
                    validation_freq=1, # default=1, Only relevant if validation data is provided. If an integer, specifies how many training epochs to run before a new validation run is performed, e.g. validation_freq=2 runs validation every 2 epochs.
                    max_queue_size=10, # default=10, Used for generator or keras.utils.Sequence input only. Maximum size for the generator queue. If unspecified, max_queue_size will default to 10.
                    workers=1, # default=1, Used for generator or keras.utils.Sequence input only. Maximum number of processes to spin up when using process-based threading. If unspecified, workers will default to 1.
                    use_multiprocessing=True, # default=False, Used for generator or keras.utils.Sequence input only. If True, use process-based threading. If unspecified, use_multiprocessing will default to False. 
                
                   )
# Out:
# Epoch 1/100
# 1028/1028 - 31s - loss: 38.7033 - mean_squared_error: 38.7033 - mean_absolute_error: 3.8126 - val_loss: 10.1860 - val_mean_squared_error: 10.1860 - val_mean_absolute_error: 2.3920 - 31s/epoch - 30ms/step
# Epoch 2/100
# 1028/1028 - 19s - loss: 8.2898 - mean_squared_error: 8.2898 - mean_absolute_error: 2.1947 - val_loss: 7.2770 - val_mean_squared_error: 7.2771 - val_mean_absolute_error: 2.0768 - 19s/epoch - 19ms/step
# Epoch 3/100
# 1028/1028 - 19s - loss: 6.2893 - mean_squared_error: 6.2893 - mean_absolute_error: 1.9185 - val_loss: 4.7590 - val_mean_squared_error: 4.7590 - val_mean_absolute_error: 1.6752 - 19s/epoch - 19ms/step
# Epoch 4/100
# 1028/1028 - 19s - loss: 5.0592 - mean_squared_error: 5.0592 - mean_absolute_error: 1.7265 - val_loss: 4.6155 - val_mean_squared_error: 4.6155 - val_mean_absolute_error: 1.6384 - 19s/epoch - 18ms/step
# Epoch 5/100
# 1028/1028 - 19s - loss: 4.4816 - mean_squared_error: 4.4816 - mean_absolute_error: 1.6198 - val_loss: 4.0356 - val_mean_squared_error: 4.0356 - val_mean_absolute_error: 1.5448 - 19s/epoch - 18ms/step
# Epoch 6/100
# 1028/1028 - 19s - loss: 4.0102 - mean_squared_error: 4.0102 - mean_absolute_error: 1.5344 - val_loss: 3.7031 - val_mean_squared_error: 3.7031 - val_mean_absolute_error: 1.4414 - 19s/epoch - 18ms/step
# Epoch 7/100
# 1028/1028 - 19s - loss: 3.9362 - mean_squared_error: 3.9362 - mean_absolute_error: 1.5120 - val_loss: 4.1427 - val_mean_squared_error: 4.1427 - val_mean_absolute_error: 1.5569 - 19s/epoch - 18ms/step
# Epoch 8/100
# 1028/1028 - 19s - loss: 3.5182 - mean_squared_error: 3.5182 - mean_absolute_error: 1.4275 - val_loss: 3.5143 - val_mean_squared_error: 3.5143 - val_mean_absolute_error: 1.4315 - 19s/epoch - 18ms/step
# Epoch 9/100
# 1028/1028 - 19s - loss: 3.1785 - mean_squared_error: 3.1785 - mean_absolute_error: 1.3614 - val_loss: 2.7027 - val_mean_squared_error: 2.7027 - val_mean_absolute_error: 1.2464 - 19s/epoch - 18ms/step
# Epoch 10/100
# 1028/1028 - 19s - loss: 3.0572 - mean_squared_error: 3.0572 - mean_absolute_error: 1.3282 - val_loss: 2.8299 - val_mean_squared_error: 2.8299 - val_mean_absolute_error: 1.2789 - 19s/epoch - 18ms/step
# Epoch 11/100
# 1028/1028 - 19s - loss: 2.7031 - mean_squared_error: 2.7031 - mean_absolute_error: 1.2538 - val_loss: 2.4888 - val_mean_squared_error: 2.4888 - val_mean_absolute_error: 1.1925 - 19s/epoch - 18ms/step
# Epoch 12/100
# 1028/1028 - 21s - loss: 2.5798 - mean_squared_error: 2.5798 - mean_absolute_error: 1.2227 - val_loss: 2.2893 - val_mean_squared_error: 2.2893 - val_mean_absolute_error: 1.1624 - 21s/epoch - 20ms/step
# Epoch 13/100
# 1028/1028 - 23s - loss: 2.4775 - mean_squared_error: 2.4775 - mean_absolute_error: 1.1939 - val_loss: 2.2509 - val_mean_squared_error: 2.2509 - val_mean_absolute_error: 1.1320 - 23s/epoch - 22ms/step
# Epoch 14/100
# 1028/1028 - 22s - loss: 2.2517 - mean_squared_error: 2.2517 - mean_absolute_error: 1.1373 - val_loss: 2.1539 - val_mean_squared_error: 2.1539 - val_mean_absolute_error: 1.1130 - 22s/epoch - 22ms/step
# Epoch 15/100
# 1028/1028 - 23s - loss: 2.1343 - mean_squared_error: 2.1343 - mean_absolute_error: 1.1070 - val_loss: 2.2049 - val_mean_squared_error: 2.2049 - val_mean_absolute_error: 1.1552 - 23s/epoch - 23ms/step
# Epoch 16/100
# 1028/1028 - 24s - loss: 1.9966 - mean_squared_error: 1.9966 - mean_absolute_error: 1.0671 - val_loss: 2.2933 - val_mean_squared_error: 2.2933 - val_mean_absolute_error: 1.1741 - 24s/epoch - 23ms/step
# Epoch 17/100
# 1028/1028 - 23s - loss: 1.8465 - mean_squared_error: 1.8465 - mean_absolute_error: 1.0257 - val_loss: 1.6569 - val_mean_squared_error: 1.6569 - val_mean_absolute_error: 0.9676 - 23s/epoch - 22ms/step
# Epoch 18/100
# 1028/1028 - 23s - loss: 1.7762 - mean_squared_error: 1.7762 - mean_absolute_error: 1.0046 - val_loss: 1.6405 - val_mean_squared_error: 1.6405 - val_mean_absolute_error: 0.9558 - 23s/epoch - 22ms/step
# Epoch 19/100
# 1028/1028 - 24s - loss: 1.6104 - mean_squared_error: 1.6104 - mean_absolute_error: 0.9534 - val_loss: 1.4191 - val_mean_squared_error: 1.4191 - val_mean_absolute_error: 0.8992 - 24s/epoch - 23ms/step
# Epoch 20/100
# 1028/1028 - 23s - loss: 1.5323 - mean_squared_error: 1.5323 - mean_absolute_error: 0.9300 - val_loss: 1.6625 - val_mean_squared_error: 1.6625 - val_mean_absolute_error: 0.9788 - 23s/epoch - 23ms/step
# Epoch 21/100
# 1028/1028 - 24s - loss: 1.4338 - mean_squared_error: 1.4338 - mean_absolute_error: 0.8978 - val_loss: 1.4468 - val_mean_squared_error: 1.4468 - val_mean_absolute_error: 0.9178 - 24s/epoch - 23ms/step
# Epoch 22/100
# 1028/1028 - 22s - loss: 1.3849 - mean_squared_error: 1.3849 - mean_absolute_error: 0.8795 - val_loss: 1.6014 - val_mean_squared_error: 1.6014 - val_mean_absolute_error: 0.9711 - 22s/epoch - 22ms/step
# Epoch 23/100
# 1028/1028 - 22s - loss: 1.6046 - mean_squared_error: 1.6046 - mean_absolute_error: 0.9387 - val_loss: 1.2423 - val_mean_squared_error: 1.2423 - val_mean_absolute_error: 0.8377 - 22s/epoch - 22ms/step
# Epoch 24/100
# 1028/1028 - 24s - loss: 1.3290 - mean_squared_error: 1.3290 - mean_absolute_error: 0.8618 - val_loss: 1.2130 - val_mean_squared_error: 1.2130 - val_mean_absolute_error: 0.8193 - 24s/epoch - 24ms/step
# Epoch 25/100
# 1028/1028 - 24s - loss: 1.2324 - mean_squared_error: 1.2324 - mean_absolute_error: 0.8287 - val_loss: 1.7909 - val_mean_squared_error: 1.7909 - val_mean_absolute_error: 1.0338 - 24s/epoch - 23ms/step
# Epoch 26/100
# 1028/1028 - 24s - loss: 1.1548 - mean_squared_error: 1.1548 - mean_absolute_error: 0.8025 - val_loss: 1.1206 - val_mean_squared_error: 1.1206 - val_mean_absolute_error: 0.7835 - 24s/epoch - 23ms/step
# Epoch 27/100
# 1028/1028 - 23s - loss: 1.1104 - mean_squared_error: 1.1104 - mean_absolute_error: 0.7840 - val_loss: 1.0534 - val_mean_squared_error: 1.0534 - val_mean_absolute_error: 0.7672 - 23s/epoch - 23ms/step
# Epoch 28/100
# 1028/1028 - 24s - loss: 1.1339 - mean_squared_error: 1.1339 - mean_absolute_error: 0.7894 - val_loss: 1.0059 - val_mean_squared_error: 1.0059 - val_mean_absolute_error: 0.7450 - 24s/epoch - 23ms/step
# Epoch 29/100
# 1028/1028 - 24s - loss: 1.0219 - mean_squared_error: 1.0219 - mean_absolute_error: 0.7527 - val_loss: 1.3069 - val_mean_squared_error: 1.3069 - val_mean_absolute_error: 0.8859 - 24s/epoch - 23ms/step
# Epoch 30/100
# 1028/1028 - 24s - loss: 1.0216 - mean_squared_error: 1.0216 - mean_absolute_error: 0.7504 - val_loss: 0.9770 - val_mean_squared_error: 0.9770 - val_mean_absolute_error: 0.7388 - 24s/epoch - 23ms/step
# Epoch 31/100
# 1028/1028 - 24s - loss: 0.9734 - mean_squared_error: 0.9734 - mean_absolute_error: 0.7342 - val_loss: 1.1712 - val_mean_squared_error: 1.1712 - val_mean_absolute_error: 0.7777 - 24s/epoch - 23ms/step
# Epoch 32/100
# 1028/1028 - 24s - loss: 1.0403 - mean_squared_error: 1.0403 - mean_absolute_error: 0.7527 - val_loss: 0.9521 - val_mean_squared_error: 0.9521 - val_mean_absolute_error: 0.7285 - 24s/epoch - 23ms/step
# Epoch 33/100
# 1028/1028 - 23s - loss: 0.9755 - mean_squared_error: 0.9755 - mean_absolute_error: 0.7308 - val_loss: 0.8585 - val_mean_squared_error: 0.8585 - val_mean_absolute_error: 0.6812 - 23s/epoch - 23ms/step
# Epoch 34/100
# 1028/1028 - 24s - loss: 0.9498 - mean_squared_error: 0.9498 - mean_absolute_error: 0.7196 - val_loss: 0.8927 - val_mean_squared_error: 0.8927 - val_mean_absolute_error: 0.6997 - 24s/epoch - 24ms/step
# Epoch 35/100
# 1028/1028 - 24s - loss: 0.8953 - mean_squared_error: 0.8953 - mean_absolute_error: 0.7027 - val_loss: 1.5703 - val_mean_squared_error: 1.5703 - val_mean_absolute_error: 0.8923 - 24s/epoch - 24ms/step
# Epoch 36/100
# 1028/1028 - 24s - loss: 0.9012 - mean_squared_error: 0.9012 - mean_absolute_error: 0.7016 - val_loss: 0.9003 - val_mean_squared_error: 0.9003 - val_mean_absolute_error: 0.7030 - 24s/epoch - 23ms/step
# Epoch 37/100
# 1028/1028 - 24s - loss: 0.9220 - mean_squared_error: 0.9220 - mean_absolute_error: 0.7090 - val_loss: 0.8653 - val_mean_squared_error: 0.8653 - val_mean_absolute_error: 0.6823 - 24s/epoch - 23ms/step
# Epoch 38/100
# 1028/1028 - 24s - loss: 0.8528 - mean_squared_error: 0.8528 - mean_absolute_error: 0.6844 - val_loss: 0.8738 - val_mean_squared_error: 0.8738 - val_mean_absolute_error: 0.6892 - 24s/epoch - 23ms/step
# Epoch 39/100
# 1028/1028 - 24s - loss: 0.8612 - mean_squared_error: 0.8612 - mean_absolute_error: 0.6856 - val_loss: 1.0389 - val_mean_squared_error: 1.0389 - val_mean_absolute_error: 0.7316 - 24s/epoch - 23ms/step
# Epoch 40/100
# 1028/1028 - 24s - loss: 0.8464 - mean_squared_error: 0.8464 - mean_absolute_error: 0.6789 - val_loss: 0.8819 - val_mean_squared_error: 0.8819 - val_mean_absolute_error: 0.7010 - 24s/epoch - 23ms/step
# Epoch 41/100
# 1028/1028 - 24s - loss: 0.9049 - mean_squared_error: 0.9049 - mean_absolute_error: 0.6969 - val_loss: 0.8557 - val_mean_squared_error: 0.8557 - val_mean_absolute_error: 0.6775 - 24s/epoch - 24ms/step
# Epoch 42/100
# 1028/1028 - 24s - loss: 0.8277 - mean_squared_error: 0.8277 - mean_absolute_error: 0.6707 - val_loss: 0.8088 - val_mean_squared_error: 0.8088 - val_mean_absolute_error: 0.6654 - 24s/epoch - 23ms/step
# Epoch 43/100
# 1028/1028 - 24s - loss: 0.7953 - mean_squared_error: 0.7953 - mean_absolute_error: 0.6587 - val_loss: 0.9047 - val_mean_squared_error: 0.9047 - val_mean_absolute_error: 0.7010 - 24s/epoch - 23ms/step
# Epoch 44/100
# 1028/1028 - 23s - loss: 0.9357 - mean_squared_error: 0.9357 - mean_absolute_error: 0.7078 - val_loss: 0.9299 - val_mean_squared_error: 0.9299 - val_mean_absolute_error: 0.7110 - 23s/epoch - 23ms/step
# Epoch 45/100
# 1028/1028 - 21s - loss: 0.7726 - mean_squared_error: 0.7726 - mean_absolute_error: 0.6477 - val_loss: 0.7985 - val_mean_squared_error: 0.7985 - val_mean_absolute_error: 0.6601 - 21s/epoch - 21ms/step
# Epoch 46/100
# 1028/1028 - 22s - loss: 0.7435 - mean_squared_error: 0.7435 - mean_absolute_error: 0.6360 - val_loss: 0.8057 - val_mean_squared_error: 0.8057 - val_mean_absolute_error: 0.6660 - 22s/epoch - 21ms/step
# Epoch 47/100
# 1028/1028 - 22s - loss: 0.7506 - mean_squared_error: 0.7506 - mean_absolute_error: 0.6422 - val_loss: 0.8535 - val_mean_squared_error: 0.8535 - val_mean_absolute_error: 0.6785 - 22s/epoch - 21ms/step
# Epoch 48/100
# 1028/1028 - 21s - loss: 0.7839 - mean_squared_error: 0.7839 - mean_absolute_error: 0.6510 - val_loss: 0.8406 - val_mean_squared_error: 0.8406 - val_mean_absolute_error: 0.6715 - 21s/epoch - 21ms/step
# Epoch 49/100
# 1028/1028 - 22s - loss: 0.7592 - mean_squared_error: 0.7592 - mean_absolute_error: 0.6449 - val_loss: 0.7768 - val_mean_squared_error: 0.7768 - val_mean_absolute_error: 0.6400 - 22s/epoch - 21ms/step
# Epoch 50/100
# 1028/1028 - 22s - loss: 0.7604 - mean_squared_error: 0.7604 - mean_absolute_error: 0.6406 - val_loss: 0.8717 - val_mean_squared_error: 0.8717 - val_mean_absolute_error: 0.6720 - 22s/epoch - 21ms/step
# Epoch 51/100
# 1028/1028 - 22s - loss: 0.7142 - mean_squared_error: 0.7142 - mean_absolute_error: 0.6240 - val_loss: 0.7842 - val_mean_squared_error: 0.7842 - val_mean_absolute_error: 0.6572 - 22s/epoch - 21ms/step
# Epoch 52/100
# 1028/1028 - 20s - loss: 0.7862 - mean_squared_error: 0.7862 - mean_absolute_error: 0.6473 - val_loss: 1.0523 - val_mean_squared_error: 1.0523 - val_mean_absolute_error: 0.7523 - 20s/epoch - 19ms/step
# Epoch 53/100
# 1028/1028 - 17s - loss: 0.7861 - mean_squared_error: 0.7861 - mean_absolute_error: 0.6495 - val_loss: 0.8216 - val_mean_squared_error: 0.8216 - val_mean_absolute_error: 0.6686 - 17s/epoch - 16ms/step
# Epoch 54/100
# 1028/1028 - 15s - loss: 0.7290 - mean_squared_error: 0.7290 - mean_absolute_error: 0.6269 - val_loss: 0.7962 - val_mean_squared_error: 0.7962 - val_mean_absolute_error: 0.6599 - 15s/epoch - 15ms/step
# Epoch 55/100
# 1028/1028 - 15s - loss: 0.6979 - mean_squared_error: 0.6979 - mean_absolute_error: 0.6168 - val_loss: 0.7358 - val_mean_squared_error: 0.7358 - val_mean_absolute_error: 0.6258 - 15s/epoch - 15ms/step
# Epoch 56/100
# 1028/1028 - 16s - loss: 0.6941 - mean_squared_error: 0.6941 - mean_absolute_error: 0.6161 - val_loss: 0.7275 - val_mean_squared_error: 0.7275 - val_mean_absolute_error: 0.6183 - 16s/epoch - 15ms/step
# Epoch 57/100
# 1028/1028 - 15s - loss: 0.7151 - mean_squared_error: 0.7151 - mean_absolute_error: 0.6234 - val_loss: 0.7296 - val_mean_squared_error: 0.7296 - val_mean_absolute_error: 0.6228 - 15s/epoch - 15ms/step
# Epoch 58/100
# 1028/1028 - 15s - loss: 0.6878 - mean_squared_error: 0.6878 - mean_absolute_error: 0.6135 - val_loss: 0.7330 - val_mean_squared_error: 0.7330 - val_mean_absolute_error: 0.6327 - 15s/epoch - 15ms/step
# Epoch 59/100
# 1028/1028 - 16s - loss: 0.6804 - mean_squared_error: 0.6804 - mean_absolute_error: 0.6092 - val_loss: 0.7485 - val_mean_squared_error: 0.7485 - val_mean_absolute_error: 0.6330 - 16s/epoch - 15ms/step
# Epoch 60/100
# 1028/1028 - 16s - loss: 0.6793 - mean_squared_error: 0.6793 - mean_absolute_error: 0.6077 - val_loss: 0.7108 - val_mean_squared_error: 0.7108 - val_mean_absolute_error: 0.6115 - 16s/epoch - 15ms/step
# Epoch 61/100
# 1028/1028 - 15s - loss: 0.7258 - mean_squared_error: 0.7258 - mean_absolute_error: 0.6250 - val_loss: 0.7642 - val_mean_squared_error: 0.7642 - val_mean_absolute_error: 0.6384 - 15s/epoch - 15ms/step
# Epoch 62/100
# 1028/1028 - 15s - loss: 0.7899 - mean_squared_error: 0.7899 - mean_absolute_error: 0.6431 - val_loss: 0.7804 - val_mean_squared_error: 0.7804 - val_mean_absolute_error: 0.6429 - 15s/epoch - 15ms/step
# Epoch 63/100
# 1028/1028 - 15s - loss: 0.6715 - mean_squared_error: 0.6715 - mean_absolute_error: 0.6041 - val_loss: 0.7311 - val_mean_squared_error: 0.7311 - val_mean_absolute_error: 0.6240 - 15s/epoch - 15ms/step
# Epoch 64/100
# 1028/1028 - 15s - loss: 0.6400 - mean_squared_error: 0.6400 - mean_absolute_error: 0.5898 - val_loss: 0.7226 - val_mean_squared_error: 0.7226 - val_mean_absolute_error: 0.6156 - 15s/epoch - 15ms/step
# Epoch 65/100
# 1028/1028 - 15s - loss: 0.6479 - mean_squared_error: 0.6479 - mean_absolute_error: 0.5932 - val_loss: 0.7322 - val_mean_squared_error: 0.7322 - val_mean_absolute_error: 0.6212 - 15s/epoch - 15ms/step
# Epoch 66/100
# 1028/1028 - 15s - loss: 0.6474 - mean_squared_error: 0.6474 - mean_absolute_error: 0.5956 - val_loss: 0.8554 - val_mean_squared_error: 0.8554 - val_mean_absolute_error: 0.6979 - 15s/epoch - 15ms/step
# Epoch 67/100
# 1028/1028 - 16s - loss: 0.6458 - mean_squared_error: 0.6458 - mean_absolute_error: 0.5920 - val_loss: 0.7152 - val_mean_squared_error: 0.7152 - val_mean_absolute_error: 0.6136 - 16s/epoch - 15ms/step
# Epoch 68/100
# 1028/1028 - 16s - loss: 0.6426 - mean_squared_error: 0.6426 - mean_absolute_error: 0.5911 - val_loss: 0.8194 - val_mean_squared_error: 0.8194 - val_mean_absolute_error: 0.6644 - 16s/epoch - 15ms/step
# Epoch 69/100
# 1028/1028 - 15s - loss: 0.6365 - mean_squared_error: 0.6365 - mean_absolute_error: 0.5884 - val_loss: 0.7188 - val_mean_squared_error: 0.7188 - val_mean_absolute_error: 0.6221 - 15s/epoch - 15ms/step
# Epoch 70/100
# 1028/1028 - 16s - loss: 0.6290 - mean_squared_error: 0.6290 - mean_absolute_error: 0.5872 - val_loss: 0.7357 - val_mean_squared_error: 0.7357 - val_mean_absolute_error: 0.6290 - 16s/epoch - 15ms/step
# Epoch 71/100
# 1028/1028 - 15s - loss: 0.6420 - mean_squared_error: 0.6420 - mean_absolute_error: 0.5899 - val_loss: 1.0289 - val_mean_squared_error: 1.0289 - val_mean_absolute_error: 0.7708 - 15s/epoch - 15ms/step
# Epoch 72/100
# 1028/1028 - 14s - loss: 0.6442 - mean_squared_error: 0.6442 - mean_absolute_error: 0.5891 - val_loss: 0.7041 - val_mean_squared_error: 0.7041 - val_mean_absolute_error: 0.6130 - 14s/epoch - 13ms/step
# Epoch 73/100
# 1028/1028 - 12s - loss: 0.6291 - mean_squared_error: 0.6291 - mean_absolute_error: 0.5842 - val_loss: 0.7328 - val_mean_squared_error: 0.7328 - val_mean_absolute_error: 0.6325 - 12s/epoch - 12ms/step
# Epoch 74/100
# 1028/1028 - 12s - loss: 0.6198 - mean_squared_error: 0.6198 - mean_absolute_error: 0.5812 - val_loss: 0.8452 - val_mean_squared_error: 0.8452 - val_mean_absolute_error: 0.6766 - 12s/epoch - 12ms/step
# Epoch 75/100
# 1028/1028 - 12s - loss: 0.6149 - mean_squared_error: 0.6149 - mean_absolute_error: 0.5786 - val_loss: 0.8779 - val_mean_squared_error: 0.8779 - val_mean_absolute_error: 0.7023 - 12s/epoch - 12ms/step
# Epoch 76/100
# 1028/1028 - 12s - loss: 0.6187 - mean_squared_error: 0.6187 - mean_absolute_error: 0.5807 - val_loss: 0.8599 - val_mean_squared_error: 0.8599 - val_mean_absolute_error: 0.6887 - 12s/epoch - 12ms/step
# Epoch 77/100
# 1028/1028 - 12s - loss: 0.6600 - mean_squared_error: 0.6600 - mean_absolute_error: 0.5967 - val_loss: 0.7020 - val_mean_squared_error: 0.7020 - val_mean_absolute_error: 0.6126 - 12s/epoch - 12ms/step
# Epoch 78/100
# 1028/1028 - 12s - loss: 0.6016 - mean_squared_error: 0.6016 - mean_absolute_error: 0.5722 - val_loss: 0.6820 - val_mean_squared_error: 0.6820 - val_mean_absolute_error: 0.5964 - 12s/epoch - 12ms/step
# Epoch 79/100
# 1028/1028 - 12s - loss: 0.5890 - mean_squared_error: 0.5890 - mean_absolute_error: 0.5648 - val_loss: 0.6888 - val_mean_squared_error: 0.6888 - val_mean_absolute_error: 0.6054 - 12s/epoch - 12ms/step
# Epoch 80/100
# 1028/1028 - 12s - loss: 0.5949 - mean_squared_error: 0.5949 - mean_absolute_error: 0.5682 - val_loss: 0.7994 - val_mean_squared_error: 0.7994 - val_mean_absolute_error: 0.6508 - 12s/epoch - 12ms/step
# Epoch 81/100
# 1028/1028 - 12s - loss: 0.5816 - mean_squared_error: 0.5816 - mean_absolute_error: 0.5631 - val_loss: 0.8251 - val_mean_squared_error: 0.8251 - val_mean_absolute_error: 0.6603 - 12s/epoch - 12ms/step
# Epoch 82/100
# 1028/1028 - 12s - loss: 0.6126 - mean_squared_error: 0.6126 - mean_absolute_error: 0.5779 - val_loss: 0.8039 - val_mean_squared_error: 0.8039 - val_mean_absolute_error: 0.6728 - 12s/epoch - 12ms/step
# Epoch 83/100
# 1028/1028 - 12s - loss: 0.6181 - mean_squared_error: 0.6181 - mean_absolute_error: 0.5753 - val_loss: 0.6475 - val_mean_squared_error: 0.6475 - val_mean_absolute_error: 0.5782 - 12s/epoch - 12ms/step
# Epoch 84/100
# 1028/1028 - 12s - loss: 0.6197 - mean_squared_error: 0.6197 - mean_absolute_error: 0.5773 - val_loss: 0.8640 - val_mean_squared_error: 0.8640 - val_mean_absolute_error: 0.6904 - 12s/epoch - 12ms/step
# Epoch 85/100
# 1028/1028 - 12s - loss: 0.6010 - mean_squared_error: 0.6010 - mean_absolute_error: 0.5669 - val_loss: 0.6840 - val_mean_squared_error: 0.6840 - val_mean_absolute_error: 0.5942 - 12s/epoch - 12ms/step
# Epoch 86/100
# 1028/1028 - 12s - loss: 0.5742 - mean_squared_error: 0.5742 - mean_absolute_error: 0.5589 - val_loss: 0.6688 - val_mean_squared_error: 0.6688 - val_mean_absolute_error: 0.5904 - 12s/epoch - 12ms/step
# Epoch 87/100
# 1028/1028 - 12s - loss: 0.5708 - mean_squared_error: 0.5708 - mean_absolute_error: 0.5585 - val_loss: 0.6492 - val_mean_squared_error: 0.6492 - val_mean_absolute_error: 0.5796 - 12s/epoch - 12ms/step
# Epoch 88/100
# 1028/1028 - 12s - loss: 0.5963 - mean_squared_error: 0.5963 - mean_absolute_error: 0.5655 - val_loss: 0.7752 - val_mean_squared_error: 0.7752 - val_mean_absolute_error: 0.6386 - 12s/epoch - 12ms/step
# Epoch 89/100
# 1028/1028 - 12s - loss: 0.5768 - mean_squared_error: 0.5768 - mean_absolute_error: 0.5606 - val_loss: 0.7084 - val_mean_squared_error: 0.7084 - val_mean_absolute_error: 0.6131 - 12s/epoch - 12ms/step
# Epoch 90/100
# 1028/1028 - 12s - loss: 0.5640 - mean_squared_error: 0.5640 - mean_absolute_error: 0.5521 - val_loss: 0.6714 - val_mean_squared_error: 0.6714 - val_mean_absolute_error: 0.5966 - 12s/epoch - 12ms/step
# Epoch 91/100
# 1028/1028 - 12s - loss: 0.6134 - mean_squared_error: 0.6134 - mean_absolute_error: 0.5764 - val_loss: 0.6904 - val_mean_squared_error: 0.6904 - val_mean_absolute_error: 0.6089 - 12s/epoch - 12ms/step
# Epoch 92/100
# 1028/1028 - 12s - loss: 0.6095 - mean_squared_error: 0.6095 - mean_absolute_error: 0.5734 - val_loss: 1.3058 - val_mean_squared_error: 1.3058 - val_mean_absolute_error: 0.8635 - 12s/epoch - 12ms/step
# Epoch 93/100
# 1028/1028 - 12s - loss: 0.6052 - mean_squared_error: 0.6052 - mean_absolute_error: 0.5721 - val_loss: 0.7015 - val_mean_squared_error: 0.7015 - val_mean_absolute_error: 0.6131 - 12s/epoch - 12ms/step
# Epoch 94/100
# 1028/1028 - 12s - loss: 0.5507 - mean_squared_error: 0.5507 - mean_absolute_error: 0.5458 - val_loss: 0.7880 - val_mean_squared_error: 0.7880 - val_mean_absolute_error: 0.6665 - 12s/epoch - 12ms/step
# Epoch 95/100
# 1028/1028 - 12s - loss: 0.5690 - mean_squared_error: 0.5690 - mean_absolute_error: 0.5562 - val_loss: 0.6548 - val_mean_squared_error: 0.6548 - val_mean_absolute_error: 0.5879 - 12s/epoch - 12ms/step
# Epoch 96/100
# 1028/1028 - 12s - loss: 0.5473 - mean_squared_error: 0.5473 - mean_absolute_error: 0.5450 - val_loss: 0.6548 - val_mean_squared_error: 0.6548 - val_mean_absolute_error: 0.5830 - 12s/epoch - 12ms/step
# Epoch 97/100
# 1028/1028 - 12s - loss: 0.5582 - mean_squared_error: 0.5582 - mean_absolute_error: 0.5513 - val_loss: 0.6483 - val_mean_squared_error: 0.6483 - val_mean_absolute_error: 0.5822 - 12s/epoch - 12ms/step
# Epoch 98/100
# 1028/1028 - 12s - loss: 0.5510 - mean_squared_error: 0.5510 - mean_absolute_error: 0.5470 - val_loss: 0.8504 - val_mean_squared_error: 0.8504 - val_mean_absolute_error: 0.6879 - 12s/epoch - 12ms/step
# Epoch 99/100
# 1028/1028 - 12s - loss: 0.7818 - mean_squared_error: 0.7818 - mean_absolute_error: 0.6120 - val_loss: 2.4029 - val_mean_squared_error: 2.4029 - val_mean_absolute_error: 1.1403 - 12s/epoch - 12ms/step
# Epoch 100/100
# 1028/1028 - 12s - loss: 1.1681 - mean_squared_error: 1.1681 - mean_absolute_error: 0.7767 - val_loss: 1.3147 - val_mean_squared_error: 1.3147 - val_mean_absolute_error: 0.7651 - 12s/epoch - 12ms/step

# %% [markdown]
# ##### Step 4 - Plot loss over epochs

# %%
# Gather the trained model's weight and bias.
trained_weight = model2.get_weights()[0]
trained_bias = model2.get_weights()[1]

  # The list of epochs is stored separately from the 
  # rest of history.
epochs = history.epoch
  
  # Gather the history (a snapshot) of each epoch.
#hist = pd.DataFrame(history.history)

  # Specifically gather the model's root mean 
  # squared error at each epoch. 
mse = history.history["mean_squared_error"]

#plot_the_model(trained_weight, trained_bias, X_test, Y_train)
plot_the_loss_curve(epochs, mse)

# %% [markdown]
# ##### Step 5 - Print Performance Summary

# %%
print("")
print('-------------------- Model Summary --------------------')
model2.summary() # print model summary
print("")
print('-------------------- Weights and Biases --------------------')
print("Too many parameters to print but you can use the code provided if needed")
print("")
#for layer in model.layers:
#    print(layer.name)
#    for item in layer.get_weights():
#        print("  ", item)
#print("")

# Print the last value in the evaluation metrics contained within history file
print('-------------------- Evaluation on Training Data --------------------')
for item in history.history:
    print("Final", item, ":", history.history[item][-1])
print("")

# Evaluate the model on the test data using "evaluate"
print('-------------------- Evaluation on Test Data --------------------')
results = model2.evaluate(X_test, Y_test)
print("")
# Out:
# -------------------- Model Summary --------------------
# Model: "biLSTM-Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Hidden-LSTM-Encoder-Layer (  (None, 128)              34816
#  Bidirectional)
#
#  Repeat-Vector-Layer (Repeat  (None, 10, 128)          0
#  Vector)
#
#  Hidden-LSTM-Decoder-Layer (  (None, 10, 128)          98816
#  Bidirectional)
#
#  Output-Layer (TimeDistribut  (None, 10, 1)            129
#  ed)
#
# =================================================================
# Total params: 133,761
# Trainable params: 133,761
# Non-trainable params: 0
# _________________________________________________________________
#
# -------------------- Weights and Biases --------------------
# Too many parameters to print but you can use the code provided if needed
#
# -------------------- Evaluation on Training Data --------------------
# Final loss : 1.1680729389190674
# Final mean_squared_error : 1.1680712699890137
# Final mean_absolute_error : 0.7767180800437927
# Final val_loss : 1.3147050142288208
# Final val_mean_squared_error : 1.314705729484558
# Final val_mean_absolute_error : 0.7650931477546692
#
# -------------------- Evaluation on Test Data --------------------
# 345/345 [==============================] - 2s 6ms/step - loss: 1.3352 - mean_squared_error: 1.3352 - mean_absolute_error: 0.7957

# %%
results
# loss: 9.2961 - mean_squared_error: 9.2960 normalize 01  loss: 8.9703 - mean_squared_error: 8.9703 - accuracy: 0.0000e+00
# Out:
# [1.3351967334747314, 1.335196614265442, 0.7957162261009216]

# %%
from keras.utils import plot_model,model_to_dot
plot_model(model2, show_shapes=True, to_file='plotmodelbilstm0810.png')

# %%
pred_test=model2.predict(X_test)
# Out:
# 345/345 [==============================] - 2s 5ms/step

# %%
Y_test.shape
#1792
# Out:
# (11011, 10, 1)

# %%
test.values.size
# Out:
# 13310

# %%
pred_test.shape
# Out:
# (11011, 10, 1)

# %%
# pred_test = scaler2.inverse_transform(pred_test.reshape(-1, pred_test.shape[-1])).reshape(pred_test.shape)
y=pred_test.flatten()
# y=scaler2.inverse_transform(y.reshape(-1,y.shape[-1])).reshape(y.shape)
z=[]
for x in range(910*95,910*96,10): #predictioon
    z.append(y[x])
z

b=Y_test.flatten() #Y test should match prediction
# b=scaler2.inverse_transform(b.reshape(-1,b.shape[-1])).reshape(b.shape)
c=[] #wtf is this
for x in range(910*95,910*96,10):
    c.append(b[x])
#c

# d=X_test.flatten() # Y train doesnt match because why
# e=[]
# for x in range(0,10000,1):
#     if(d[x]==0):
#         print(x)
#     e.append(d[x])
# # e

# %%
# Plot (actual and predicted) for test (out of time) data
fig = go.Figure()

# #Trace for actual val
# fig.add_trace(go.Scatter(x=np.array(test.columns),
#                          y=np.array(test.values).flatten(),
#                          mode='lines',
#                          name='Subsidence - Actual (Test)',
#                          opacity=0.8,
#                          line=dict(color='black', width=1)
#                         ))
# fig.add_trace(go.Scatter(x=np.array(test.columns),
#                          y=e,
#                          mode='lines',
#                          name='Subsidence - Actual (YTrain)',
#                          opacity=0.8,
#                          line=dict(color='pink', width=1)
#                         ))

fig.add_trace(go.Scatter(x=np.array(test.columns[10:]),
                         y=c,
                         mode='lines',
                         name='Subsidence - Actual (YTest)',
                         opacity=0.8,
                         line=dict(color='grey', width=5)
                        ))


# Trace for predicted 
fig.add_trace(go.Scatter(x=np.array(test.columns[10:]),
                         y=z,
                         mode='lines',
                         name='Subsidence - Predicted ',
                         opacity=0.8,
                         line=dict(color='red', width=5)
                        ))

# Change chart background color
fig.update_layout(dict(plot_bgcolor = 'white'))

# Update axes lines
fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='lightgrey', 
                 zeroline=True, zerolinewidth=1, zerolinecolor='lightgrey', 
                 showline=True, linewidth=1, linecolor='black',
                 title='Month-Year'
                )

fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='lightgrey', 
                 zeroline=True, zerolinewidth=1, zerolinecolor='lightgrey', 
                 showline=True, linewidth=1, linecolor='black',
                 title='Subsidence'
                )

# Set figure title
fig.update_layout(title=dict(text="Subsidence", font=dict(color='black')),
                  legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1)
                 )
fig.show()
